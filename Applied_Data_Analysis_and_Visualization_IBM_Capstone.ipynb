# %% [markdown]
# # Applied Data Analysis & Visualization
#
# This notebook consolidates multiple hands-on labs from the **IBM Data Analyst Professional Certificate**.
#
# It demonstrates an end-to-end data analytics workflow including:
# - Data collection (APIs, web scraping)
# - Data cleaning and preprocessing
# - Exploratory and statistical analysis
# - Visualization and reporting
#
# The goal of this consolidated notebook is to present a clean, professional portfolio artifact suitable for GitHub.

# %% [markdown]
# ---
#
# ## Section from `PY0101EN_5_3_Requests_HTTP.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# <h1> Review Of Accessing APIs</h1>
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab, you will be able to:
#
# *   Understand HTTP
# *   Analyze HTTP Requests

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#Overview-of-HTTP">Overview of HTTP </a>
#             <ul>
#                 <li><a href="#Uniform-Resource-Locator-(URL)">Uniform Resource Locator: URL</a></li>
#                  <li><a href="#Request">Request</a></li>
#                 <li><a href="#Response">Response</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#Requests-in-Python">Requests in Python  </a>
#             <ul>
#                 <li><a href="#Get-Request-with-URL-Parameters">Get Request with URL Parameters</a></li>
#                 <li><a href="#Post-Requests">Post Requests </a></li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# ## Overview of HTTP

# %% [markdown]
# When you, the **client**, access a web page, your browser sends an **HTTP** request to the **server** where the page is hosted. The server tries to locate the desired **resource** by default "<code>index.html</code>". If your request is successful, the server will send the object to the client in an **HTTP response**, which includes information like the type of the **resource**, the length of the **resource**, and other information.
#
# <p>
# The figure below represents the process. The circle on the left represents the client, the circle on the right represents the web server. The table under the web server represents a list of resources stored in the web server. In  this case an <code>HTML</code> file, <code>png</code> image, and <code>txt</code> file .
# </p>
# <p>
# The <b>HTTP</b> protocol enables you to send and receive information through the web including webpages, images, and other web resources. In this lab, you will explore the Requests library for interacting with the <code>HTTP</code> protocol.
# </p

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/reqest_basics.png" width="750" align="center">
#
# </div>

# %% [markdown]
# ## Uniform Resource Locator (URL)

# %% [markdown]
# Uniform resource locator (URL) is the common way to find resources on the web.  A URL can be broken down into three main parts:
#
# <ul>
#     <li><b>Scheme</b>: The protocol used, which in this lab will always be<code>http://</code>  </li>
#     <li><b> Internet address or  Base URL</b>: Used to locate the resource. Examples include <code>www.ibm.com</code> and  <code> www.gitlab.com </code> </li>
#     <li><b>Route</b>: Location on the web server for example: <code>/images/IDSNlogo.png</code> </li>
# </ul>

# %% [markdown]
# You may also hear the term Uniform Resource Identifier (URI). URL are actually a subset of URIs. Another popular term is endpoint, which refers to the URL of an operation provided by a web server.

# %% [markdown]
# ## Request

# %% [markdown]
# The process can be broken into the <b>Request</b> and <b>Response </b> process.  The request using the get method is partially illustrated below. In the start line we have the <code>GET</code> method, this is an <code>HTTP</code> method. Also the location of the resource  <code>/index.html</code> and the <code>HTTP</code> version. The Request header passes additional information with an <code>HTTP</code> request:

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/reqest_messege.png" width="400" align="center">
# </div>

# %% [markdown]
# When an <code>HTTP</code> request is made, an <code>HTTP</code> method is sent, this tells the server what action to perform.  A list of several <code>HTTP</code> methods is shown below. We will review more examples later.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/SC6-zFofaLr-ILglB1xFGA/HTTP%20image.png" width="900" align="center">
# </div>

# %% [markdown]
# ## Response

# %% [markdown]
# The figure below represents the response; the response start line contains the version number <code>HTTP/1.0</code>, a status code (200) meaning success, followed by a descriptive phrase (OK). The response header contains useful information. Finally, we have the response body containing the requested file, an <code> HTML </code> document.  It should be noted that some requests have headers.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/kGeR47UyGjoLBL8R9yVH5Q/Response%20image.png" width="600" align="center">
# </div>

# %% [markdown]
# Some status code examples are shown in the table below, the prefix indicates the class. These are shown in yellow, with actual status codes shown in  white. Check out the following <a href="https://developer.mozilla.org/en-US/docs/Web/HTTP/Status?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">link </a> for more descriptions.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/status_code.png" width="300" align="center">
# </div>

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install requests
# !pip install pillow

# %% [markdown]
# ## Requests in Python

# %% [markdown]
# Requests is a Python Library that allows you to send <code>HTTP/1.1</code> requests easily. We can import the library as follows:

# %%
import requests

# %% [markdown]
# We will also use the following libraries:

# %%
import os
from PIL import Image
from IPython.display import IFrame

# %% [markdown]
# You can make a <code>GET</code> request via the method <code>get</code> to [www.ibm.com](http://www.ibm.com/?utm_source=Exinfluencer&utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01&utm_medium=Exinfluencer&utm_term=10006555):

# %%
url='https://www.ibm.com/'
r=requests.get(url)

# %% [markdown]
# We have the response object <code>r</code>, this has information about the request, like the status of the request. You can view the status code using the attribute <code>status_code</code>.

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# You can view the request headers:

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.32.4', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=1C9F315DAAA24F9DE31281FFAF12873E~-1~...~-1~-1~-1~-1~-1; bm_sz=F9260A4993D4E2354180A602F23628C0~~4338224~3553072'}

# %% [markdown]
# You can view the request body, in the following line, as there is nobody for a get request we get <code>None</code>:

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %% [markdown]
# You can view the <code>HTTP</code> response header using the attribute <code>headers</code>. This returns a python dictionary of <code>HTTP</code> response headers.

# %%
header=r.headers
print(r.headers)
# print(header) # Added myself
# Out:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Wed, 14 Jan 2026 03:01:31 GMT', 'ETag': '"2e354-64850533bf68a-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=600', 'Expires': 'Wed, 14 Jan 2026 03:20:56 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Wed, 14 Jan 2026 03:10:56 GMT', 'Content-Length': '38051', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %% [markdown]
# You can obtain the date the request was sent using the key <code>Date</code>.

# %%
header['date']
# Out:
# 'Wed, 14 Jan 2026 03:10:56 GMT'

# %% [markdown]
# <code>Content-Type</code> indicates the type of data:

# %%
header['Content-Type']
# Out:
# 'text/html;charset=utf-8'

# %% [markdown]
# You can also check the <code>encoding</code>:

# %%
r.encoding
# Out:
# 'utf-8'

# %% [markdown]
# As the <code>Content-Type</code> is <code>text/html</code> you can use the attribute <code>text</code> to display the <code>HTML</code> in the body. You can review the first 100 characters:

# %%
r.text[0:100]
# Out:
# ' \n<!DOCTYPE HTML>\n\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n'

# %% [markdown]
# You can load other types of data for non-text requests, like images. Consider the URL of the following image:

# %%
# Use single quotation marks for defining string
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png'

# %% [markdown]
# You can make a get request:

# %%
r=requests.get(url)

# %% [markdown]
# You can look at the response header:

# %%
print(r.headers)
# Out:
# {'Date': 'Wed, 14 Jan 2026 03:17:20 GMT', 'X-Clv-Request-Id': '708970d3-cc42-47ec-8630-83d18dd49325', 'Server': 'Cleversafe', 'X-Clv-S3-Version': '2.5', 'Accept-Ranges': 'bytes', 'x-amz-request-id': '708970d3-cc42-47ec-8630-83d18dd49325', 'ETag': '"8bb44578fff8fdcc3d2972be9ece0164"', 'Content-Type': 'image/png', 'Last-Modified': 'Wed, 16 Nov 2022 03:32:41 GMT', 'Content-Length': '78776'}

# %% [markdown]
# You can see the <code>'Content-Type'</code>

# %%
r.headers['Content-Type']
# Out:
# 'image/png'

# %% [markdown]
# An image is a response object that contains the image as a <a href="https://docs.python.org/3/glossary.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01#term-bytes-like-object">bytes-like object</a>. As a result, we must save it using a file object. First, you specify the <u>file path and
# name</u>

# %%
path=os.path.join(os.getcwd(),'image.png') # getcwd: get Current Working Directory

# %% [markdown]
# You save the file, in order to access the body of the response we use the attribute <code>content</code> then save it using the <code>open</code> function and write <code>method</code>:

# %%
with open(path,'wb') as f:
    f.write(r.content)

# %% [markdown]
# You can view the image:

# %%
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1880x656>

# %% [markdown]
# <h3>Question: Download a file </h3>

# %% [markdown]
# Consider the following URL:

# %% [markdown]
# <code>URL = <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt</code>

# %% [markdown]
# Write the commands to download the txt file in the given link.

# %%
from typing import Text
## Write your code here
url2 = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
r2 = requests.get(url2)
# print(r2.headers)
# r2.headers['Content-Type']
# print(r2.text)


path = os.path.join(os.getcwd(), "Example1.txt")

with open(path, "wb") as f:
    f.write(r2.text)

# %%
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
# path=os.path.join(os.getcwd(),'example1.txt')
# r=requests.get(url)
# with open(path,'wb') as f:
#     f.write(r.content)
#
# ```
#
# </details>

# %% [markdown]
# ## Get Request with URL Parameters

# %% [markdown]
# You can use the <b>GET</b> method to modify the results of your query, for example, retrieving data from an API. We send a <b>GET</b> request to the  server. As before, we have the <b>Base URL</b>, in the <b>Route</b> we append <code>/get</code>, this indicates we would like to preform a <code>GET</code> request. This is demonstrated in the following table:

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/HvW_UIwnCUtHR7SKIJHqtQ/base-image-file.jpg" width="400" align="center">
# </div>

# %% [markdown]
# The Base URL is for <code>[http://httpbin.org/](http://httpbin.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01)</code>. It is a simple HTTP Request and Response service. The <code>URL</code> in Python is given by:

# %%
url_get='http://httpbin.org/get'

# %% [markdown]
# A <a href="https://en.wikipedia.org/wiki/Query_string?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">query string</a> is a part of a uniform resource locator (URL), it sends other information to the web server. The start of the query is a <code>?</code>, followed by a series of parameter and value pairs, as shown in the table below. The first parameter name is <code>name</code> and the value is <code>Joseph</code>. The second parameter name is <code>ID</code> and the Value is <code>123</code>. Each pair, parameter, and value is separated by an equals sign, <code>=</code>.
# The series of pairs is separated by the ampersand <code>&</code>.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#          <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/query_string.png" width="500" align="center">
# </div>

# %% [markdown]
# To create a Query string, add a dictionary. The keys are the parameter names and the values are the value of the Query string.

# %%
payload={"name":"Joseph","ID":"123"}

# %% [markdown]
# Then passing the dictionary <code>payload</code> to the <code>params</code> parameter of the <code> get()</code> function:

# %%
r=requests.get(url_get,params=payload)

# %% [markdown]
# You can print out the <code>URL</code> and see the name and values.

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %% [markdown]
# There is no request body.

# %%
print("request body:", r.request.body)
# Out:
# request body: None

# %% [markdown]
# You can print out the status code.

# %%
print(r.status_code)
# Out:
# 200

# %% [markdown]
# You can view the response as text:

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6967261c-0e5221d46127d2190b5ea831"
#   },
#   "origin": "35.221.24.165",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %% [markdown]
# You can look at the <code>'Content-Type'</code>.

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %% [markdown]
# As the content <code>'Content-Type'</code> is in the <code>JSON</code> format, you can use the method <code>json()</code>, it returns a Python <code>dict</code>:

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.4',
#   'X-Amzn-Trace-Id': 'Root=1-6967261c-0e5221d46127d2190b5ea831'},
#  'origin': '35.221.24.165',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %% [markdown]
# The key <code>args</code> has the name and values:

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# ## Post Requests

# %% [markdown]
# Like a <code>GET</code> request, a <code>POST</code> is used to send data to a server, but the <code>POST</code> request sends the data in a request body. In order to send the Post Request in Python, in the <code>URL</code> you can change the route to <code>POST</code>:

# %%
url_post='http://httpbin.org/post'

# %% [markdown]
# This endpoint will expect data as a file or as a form. A form is convenient way to configure an HTTP request to send data to a server.

# %% [markdown]
# To make a <code>POST</code> request we use the <code>post()</code> function, the variable <code>payload</code> is passed to the parameter <code> data </code>:

# %%
try:
    response = requests.post(url_post, data=payload)
    if response.status_code == 200:
        print("Response JSON:", response.json())
    else:
        print(f"HTTP Error: {response.status_code} - {response.reason}")
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Response JSON: {'args': {}, 'data': '', 'files': {}, 'form': {'ID': '123', 'name': 'Joseph'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '18', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.4', 'X-Amzn-Trace-Id': 'Root=1-69672737-64ae04793d8a21d92264f6f8'}, 'json': None, 'origin': '35.221.24.165', 'url': 'http://httpbin.org/post'}

# %% [markdown]
# Comparing the URL from the response object of the <code>GET</code> and <code>POST</code> request you see the <code>POST</code> request has no name or value pairs.

# %%
print("POST request URL:",response.url )
print("GET request URL:",r.url)
# Out:
# POST request URL: http://httpbin.org/post
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123

# %% [markdown]
# You can compare the <code>POST</code> and <code>GET</code> request body, you see only the <code>POST</code> request has a body:

# %%
print("POST request body:",response.request.body)
print("GET request body:",r.request.body)
# Out:
# POST request body: name=Joseph&ID=123
# GET request body: None

# %% [markdown]
# You can view the form as well:

# %%
response.json()['form']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# There is a lot more you can do. Check out <a href="https://requests.readthedocs.io/en/master/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Requests </a> for more.

# %% [markdown]
# <hr>
#
# <p>Congratulations, you have completed your hands-on lab on Review Of Accessing APIs.
# <hr>

# %% [markdown]
# ## Authors
#
# <p><a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01" target="_blank">Joseph Santarcangelo</a>

# %% [markdown]
# ### Other Contributors
#
# <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description           |
# | ----------------- | ------- | ---------- | ---------------------------- |
# | 2024-10-04        | 2.5     | Madhusudan | ID reviewed                  |
# | 2024-05-23        | 2.5     | Madhusudan | ID reviewed                  |
# | 2023-11-02        | 2.4     | Abhishek Gagneja | Updated instructions   |
# | 2023-06-07        | 2.3     |Akansha Yadav| Spell Check                 |
# | 2021-12-20        | 2.1     | Malika     | Updated the links            |
# | 2020-09-02        | 2.0     | Simran     | Template updates to the file |
# |                   |         |            |                              |
# |                   |         |            |                              |
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Collecting_job_data_using_APIs_Lab - Copy.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data using Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ><strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload the file into your current Jupyter environment using the upload button in your Jupyter interface. Ensure that the file is in the same folder as your working .ipynb file.
#
# Step 2: If working in a local Jupyter environment, use the "Upload" button in your Jupyter interface to upload the Jobs_API notebook into the same folder as your current .ipynb file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG">
#
# Step3:  Open the Jobs_API notebook, and run all the cells to start the Flask application. Once the server is running, you can access the API from the URL provided in the notebook.
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: https://www.kaggle.com/promptcloud/jobs-on-naukricom under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'}, {'craft': 'ISS', 'name': 'Nikolai Chub'}, {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'}, {'craft': 'ISS', 'name': 'Matthew Dominick'}, {'craft': 'ISS', 'name': 'Michael Barratt'}, {'craft': 'ISS', 'name': 'Jeanette Epps'}, {'craft': 'ISS', 'name': 'Alexander Grebenkin'}, {'craft': 'ISS', 'name': 'Butch Wilmore'}, {'craft': 'ISS', 'name': 'Sunita Williams'}, {'craft': 'Tiangong', 'name': 'Li Guangsu'}, {'craft': 'Tiangong', 'name': 'Li Cong'}, {'craft': 'Tiangong', 'name': 'Ye Guangfu'}], 'number': 12, 'message': 'success'}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 12

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 12 astronauts on ISS
# And their names are :
# Oleg Kononenko
# Nikolai Chub
# Tracy Caldwell Dyson
# Matthew Dominick
# Michael Barratt
# Jeanette Epps
# Alexander Grebenkin
# Butch Wilmore
# Sunita Williams
# Li Guangsu
# Li Cong
# Ye Guangfu

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# * Los Angeles
# * New York
# * San Francisco
# * Washington DC
# * Seattle
# * Austin
# * Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json#### Write a function to get the number of jobs for the Python technology.<br>
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#   Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01">link</a>
#
#  ##### The keys in the json are
#  * Job Title
#
#  * Job Experience Required
#
#  * Key Skills
#
#  * Role Category
#
#  * Location
#
#  * Functional Area
#
#  * Industry
#
#  * Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json">json</a> URL.

# %%
api_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json"

# Call the API
response = requests.get(api_url)
# Convert JSON response to an objects
data = response.json()

def get_number_of_jobs_T(technology):
    # Payload (params) sent to the API
    payload = {
        "Key Skills": technology
    }
    # r = requests.get(api_url,params=payload)
    # Initialize counter
    number_of_jobs = 0

    # Loop through each job posting
    for job in data:
        if technology.lower() in job["Key Skills"].lower():
            number_of_jobs += 1

    return technology,number_of_jobs

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")
# Out:
# ('Python', 1173)

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
# def get_number_of_jobs_L(location):
#   # Payload (params) sent to the API
#     payload = {
#         "Location": location,
#     }
#     number_of_jobs = 0
#     for job in data:
#       if location == 'houston':
#         number_of_jobs += 1
#     #your coe goes here
#     return location,number_of_jobs

def get_number_of_jobs_L(location):
    number_of_jobs = 0
    # Payload (params) sent to the API
    payload = {
        "Location": location,
    }
    for job in data:
        if job["Location"].lower() == location.lower():
            number_of_jobs += 1

    return location, number_of_jobs

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
#your code goes here
get_number_of_jobs_L('Houston')
# Out:
# ('Houston', 3339)

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all technologies for which you need to find the number of jobs postings.

# %%
#your code goes here
technologies = [
    "Python",
    "Java",
    "C++",
    "JavaScript",
    "SQL",
    "Scala"
]

# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
import requests
import pandas as pd

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here
from openpyxl import Workbook        # imports Workbook class from module openpyxl
wb=Workbook()                        # creates a workbook object
ws=wb.active                         # uses the active worksheet

# %% [markdown]
# Find the number of jobs postings for each of the technology in the above list.
# Write the technology name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here
for t in technologies:
  _, number_of_jobs = get_number_of_jobs_T(t)
  # number_of_jobs = get_number_of_jobs_T(t)
  ws.append([t,   number_of_jobs])

# %% [markdown]
# Save into an excel spreadsheet named **job-postings.xlsx**.

# %%
#your code goes here
wb.save("job-postings.xlsx")

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here
technologies_2 = [
    "C",
    "C++",
    "C#",
    "Java",
    "JavaScript",
    "Python",
    "Scala",
    "Oracle",
    "SQL Server",
    "MySQL Server",
    "PostgreSQL",
    "MongoDB"
]
for t in technologies_2:
  _, number_of_jobs = get_number_of_jobs_T(t)
  ws.append([t,   number_of_jobs])
wb.save("job-postings_2.xlsx")

# %% [markdown]
# ## Authors

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# Copyright © IBM Corporation.

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla        | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>

# %% [markdown]
# ---
#
# ## Section from `Web_Scraping_Lab.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data  = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(data, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>
# Salary survey results of programming languages
# </title>
# <style>
# table, th, td {
#   border: 1px solid black;
# }
# </style>
# </head>
# <body>
# <hr/>
# <h2>Popular Programming Languages</h2>
# <hr/>
# <p>Finding out which is the best language is a tough task. A programming language is created to solve a specific problem. A language which is good for task A may not be able to properly handle task B. Comparing programming language is never easy. What we can do, however, is find which is popular in the industry.</p>
# <p>There are many ways to find the popularity of a programming languages. Counting the number of google searchs for each language is a simple way to find the popularity. GitHub and StackOverflow also can give some good pointers.</p>
# ...

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
table = soup.find('table')
for row in table.find_all('tr'):
  col = row.find_all('td')
  col[1] = col[1].text
  col[2] = col[3].text
  print(col[1], col[2])
# Out:
# Language Average Annual Salary
# Python $114,383
# Java $101,013
# R $92,037
# Javascript $110,981
# Swift $130,801
# C++ $113,865
# C# $88,726
# PHP $84,727
# SQL $84,793
# Go $94,082

# %%
table = soup.find('table')
scraped_data = []
for row in table.find_all('tr'):
  col = row.find_all('td')
  col[1] = col[1].text
  col[2] = col[3].text
  print(col[1], col[2])
  scraped_data.append([col[1], col[2]])
# Out:
# Language Average Annual Salary
# Python $114,383
# Java $101,013
# R $92,037
# Javascript $110,981
# Swift $130,801
# C++ $113,865
# C# $88,726
# PHP $84,727
# SQL $84,793
# Go $94,082

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
# your code goes here
import pandas as pd

df = pd.DataFrame(scraped_data[1:], columns=scraped_data[0])
df.to_csv("popular-languages.csv", index=False)

print("popular-languages.csv saved successfully!")
# Out:
# popular-languages.csv saved successfully!

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).

# %% [markdown]
# ---
#
# ## Section from `Web_Scraping_Review_Lab.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/case-studies/ibm-client-zero?lnk=hpls1caen
# https://www.ibm.com/products/watsonx-orchestrate?lnk=hpls2caen
# https://www.ibm.com/think/insights/2026-resolutions-for-ai-and-technology-leaders?lnk=hprc1caen
# https://www.ibm.com/account/reg/us-en/signup?formid=urx-54227&lnk=hprc2caen
# https://www.ibm.com/account/reg/us-en/signup?formid=urx-54203&lnk=hprc3caen
# https://www.ibm.com/new/announcements/introducing-ibm-sovereign-core-a-new-software-foundation-for-sovereignty?lnk=hprc4caen
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs1caen
# https://www.ibm.com/case-studies/us-open?lnk=hpcs2caen
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs3caen
# https://www.ibm.com/case-studies/sixt?lnk=hpcs4caen
# https://www.ibm.com/case-studies/ufc?lnk=hpcs5caen
# https://www.ibm.com/products/offers-and-discounts?lnk=hpbt1caen
# https://www.ibm.com/software?lnk=hpfp1caen
# https://www.ibm.com/solutions/ai-agents?lnk=hpfp2caen
# ...

# %%
img_src = soup.find_all('img')   # Myself the whole block
for i in img_src:
  print(i.get('src'))
# print((soup.find_all('img')).get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/ibm-homepage-agents-yellow-2?ts=1768833901082&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm2569_client_zero_procurement?ts=1768833921562&dpr=off
# https://assets.ibm.com/is/image/ibm/1366_blog_thumbnail_1456x728_copy_2x_3b0ec3be0f-16x9?ts=1768836095243&dpr=off
# https://assets.ibm.com/is/image/ibm/adobestock_85065000?ts=1768834478979&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_ferrari_video_thumb_01?ts=1766225075014&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-crowd-court?ts=1764684351482&dpr=off
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1764684394381&dpr=off
# https://assets.ibm.com/is/image/ibm/sixt-smarter-business-case-study-regular-medium-ls?ts=1766229002145&dpr=off
# https://assets.ibm.com/is/image/ibm/1731592760476?ts=1764684605269&dpr=off
# https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1768833778553&dpr=off
# ...

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/ibm-homepage-agents-yellow-2?ts=1768833901082&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm2569_client_zero_procurement?ts=1768833921562&dpr=off
# https://assets.ibm.com/is/image/ibm/1366_blog_thumbnail_1456x728_copy_2x_3b0ec3be0f-16x9?ts=1768836095243&dpr=off
# https://assets.ibm.com/is/image/ibm/adobestock_85065000?ts=1768834478979&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_ferrari_video_thumb_01?ts=1766225075014&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-crowd-court?ts=1764684351482&dpr=off
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1764684394381&dpr=off
# https://assets.ibm.com/is/image/ibm/sixt-smarter-business-case-study-regular-medium-ls?ts=1766229002145&dpr=off
# https://assets.ibm.com/is/image/ibm/1731592760476?ts=1764684605269&dpr=off
# https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1768833778553&dpr=off
# ...

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
# tr_obj = table.find_all('tr')

# %%
# for r in tr_obj:
#   col = r.find_all('td')

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    # print("{}--->{}".format(color_name,color_code))
    print(f"{color_name}--->{color_code}")
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!--
# ## Change Log
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-10-29  | 0.2  | Madhusudhan Moole |  Updated lab |
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `M1ExploreDataSet_lab_V2.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploring the Dataset**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data exploration is the initial phase of data analysis where we aim to understand the data's characteristics, identify patterns, and uncover potential insights. It is a crucial step that helps us make informed decisions about subsequent analysis.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Summarize the key characteristics of a dataset.
# -   Identify different data types commonly used in data analysis.

# %% [markdown]
# ### Install the required library

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %% [markdown]
# <h3>Read Data</h3>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# # Hands on Lab

# %% [markdown]
# ## Explore the dataset

# %% [markdown]
# It is a good idea to print the top 5 rows of the dataset to get a feel of how the dataset will look.

# %% [markdown]
# Display the top 5 rows and columns from your dataset.

# %%
## Write your code here
# df.head()
df['Age']
# Out:
# 0        Under 18 years old
# 1           35-44 years old
# 2           45-54 years old
# 3           18-24 years old
# 4           18-24 years old
#                 ...
# 65452       18-24 years old
# 65453       18-24 years old
# 65454       35-44 years old
# 65455       25-34 years old
# 65456     65 years or older
# Name: Age, Length: 65457, dtype: object

# %% [markdown]
# ## Find out the number of rows and columns

# %% [markdown]
# Start by exploring the numbers of rows and columns of data in the dataset.

# %% [markdown]
# Print the number of rows in the dataset.

# %%
## Write your code here
print(df.shape[0])
print(len(df))
# Out:
# 65457
# 65457

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Print the number of columns in the dataset.

# %%
## Write your code here
print(df.shape[1])
print(len(df.columns))
# Out:
# 114
# 114

# %% [markdown]
# ## Identify the data types of each column

# %% [markdown]
# Explore the dataset and identify the data types of each column.

# %% [markdown]
# Print the datatype of all columns.

# %%
## Write your code here
for col in df.columns:
  print(col, df[col].dtype)
# Out:
# ResponseId int64
# MainBranch object
# Age object
# Employment object
# RemoteWork object
# Check object
# CodingActivities object
# EdLevel object
# LearnCode object
# LearnCodeOnline object
# TechDoc object
# YearsCode object
# YearsCodePro object
# DevType object
# OrgSize object
# PurchaseInfluence object
# BuyNewTool object
# BuildvsBuy object
# TechEndorse object
# Country object
# Currency object
# CompTotal float64
# LanguageHaveWorkedWith object
# LanguageWantToWorkWith object
# LanguageAdmired object
# DatabaseHaveWorkedWith object
# DatabaseWantToWorkWith object
# DatabaseAdmired object
# PlatformHaveWorkedWith object
# PlatformWantToWorkWith object
# PlatformAdmired object
# WebframeHaveWorkedWith object
# WebframeWantToWorkWith object
# WebframeAdmired object
# EmbeddedHaveWorkedWith object
# EmbeddedWantToWorkWith object
# EmbeddedAdmired object
# MiscTechHaveWorkedWith object
# MiscTechWantToWorkWith object
# MiscTechAdmired object
# ToolsTechHaveWorkedWith object
# ...

# %% [markdown]
# Print the mean age of the survey participants.

# %%
import numpy as np
# for col in df.columns:
#   print(col, df[col].dtype)

# df.insert(2, "numeric-age", np.nan)
# for row in df:
#   if df['Age'] == 'Under 18 years old':
#     df['numeric-age'] = 17
#   elif df['Age'] == '65 years or older':
#     df['numeric-age'] = 66
#   else:
#     df["numeric-age"] = (
#     df["Age_Range"]
#     .str.extract(r"(\d+)\s*-\s*(\d+)")   # extract numbers
#     .astype(float)
#     .mean(axis=1)
#     )
  # print(df["numeric-age"])

df["numeric-age"] = df["Age"].map({
    "Under 18 years old": 17,
    "18-24 years old": 21,
    "25-34 years old": 29.5,
    "35-44 years old": 39.5,
    "45-54 years old": 49.5,
    "55-64 years old": 59.5,
    "65 years or older": 65
})
print(df["numeric-age"])


# import numpy as np

# def convert_age(age):
#     if isinstance(age, str):
#         if "-" in age:
#             low, high = age.split()[0].split("-")
#             return (int(low) + int(high)) / 2
#         elif "Under 18" in age:
#             return 17
#         elif "65" in age:
#             return 65
#         else:
#             return np.nan
#     return np.nan

# df["Age_Numeric"] = df["Age"].apply(convert_age)
# print(df["Age_Numeric"])
# Out:
# 0        17.0
# 1        39.5
# 2        49.5
# 3        21.0
# 4        21.0
#          ...
# 65452    21.0
# 65453    21.0
# 65454    39.5
# 65455    29.5
# 65456    65.0
# Name: numeric-age, Length: 65457, dtype: float64

# %%
# print(df['Age_Numeric'].mean())
print(df['numeric-age'].mean())
# Out:
# 32.98774084593536

# %%
## Write your code here
# print(df['Age'].head(50))
# print(df['Age'].mean())

# %% [markdown]
# The dataset is the result of a world wide survey. Print how many unique countries are there in the Country column.

# %%
## Write your code here
# print(df['Country'].unique)
print(len(df['Country'].unique()))
# Out:
# 186

# %% [markdown]
# Copyright ©  IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_Exploratory_Data_Analysis.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Exploratory Data Analysis**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis or EDA.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Examine the structure of a dataset.
#
# - Handle missing values effectively.
#
# - Conduct summary statistics on key columns.
#
# - Analyze employment status, job satisfaction, programming language usage, and trends in remote work.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# #### Step 1: Install and Import Libraries

# %% [markdown]
# Install the necessary libraries for data manipulation and visualization.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Step 2: Load and Preview the Dataset
# Load the dataset from the provided URL. Use df.head() to display the first few rows to get an overview of the structure.

# %%
# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# Display the first few rows of the dataset
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2                     I am a developer by profession
# 2           3                     I am a developer by profession
# 3           4                              I am learning to code
# 4           5                     I am a developer by profession
# 5           6                        I code primarily as a hobby
# 6           7  I am not primarily a developer, but I write co...
# 7           8                              I am learning to code
# 8           9                        I code primarily as a hobby
# 9          10                     I am a developer by profession
#
#                   Age                                         Employment  \
# 0  Under 18 years old                                Employed, full-time
# 1     35-44 years old                                Employed, full-time
# ...

# %% [markdown]
# #### Step 3: Handling Missing Data

# %% [markdown]
# Identify and manage missing values in critical columns such as `Employment`, `JobSat`, and `RemoteWork`. Implement a strategy to fill or drop these values, depending on the significance of the missing data.

# %%
# df[ 'JobSat'].head(30)

# %%
## Write your code here
df[["Employment", "JobSat", "RemoteWork"]].isna().sum()

# df['JobSat'] = df['JobSat'].fillna(df['JobSat'].median())
df = df.dropna(subset=["JobSat"])
# df['Employment'] = df['Employment'].fillna(df['Employment'].mode(dropna=True).iloc[0])
df['RemoteWork'] = df['RemoteWork'].fillna(df["RemoteWork"].mode(dropna=True).iloc[0])

df[["Employment", "JobSat", "RemoteWork"]].isna().sum()
df
# Out:
#        ResponseId                                         MainBranch  \
# 10             11  I used to be a developer by profession, but no...
# 12             13                     I am a developer by profession
# 15             16                     I am a developer by profession
# 18             19                     I am a developer by profession
# 20             21  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 65178       65179                     I am a developer by profession
# 65241       65242                     I am a developer by profession
# 65265       65266                     I am a developer by profession
# 65351       65352                     I am a developer by profession
# 65412       65413                     I am a developer by profession
#
#                    Age                                         Employment  \
# ...

# %% [markdown]
# #### Step 4: Analysis of Experience and Job Satisfaction

# %% [markdown]
# Analyze the relationship between years of professional coding experience (`YearsCodePro`) and job satisfaction (`JobSat`). Summarize `YearsCodePro` and calculate median satisfaction scores based on experience ranges.
#
# - Create experience ranges for `YearsCodePro` (e.g., `0-5`, `5-10`, `10-20`, `>20` years).
#
# - Calculate the median `JobSat` for each range.
#
# - Visualize the relationship using a bar plot or similar visualization.

# %%
## Write your code here

# Select the first YearsCodePro column (safe if duplicates exist)
years = df["YearsCodePro"]

# Clean common string values
years = years.replace({
    "Less than 1 year": 0,
    "More than 50 years": 50
})

# Convert to numeric
years = pd.to_numeric(years, errors="coerce")

df["YearsCodePro_Clean"] = years

# %%
import numpy as np

bins = [-1, 5, 10, 20, np.inf]
labels = ["0–5 years", "5–10 years", "10–20 years", "20+ years"]

df["ExperienceRange"] = pd.cut(
    df["YearsCodePro_Clean"],
    bins=bins,
    labels=labels
)

# %%
median_jobsat = (
    df.groupby("ExperienceRange")["JobSat"]
    .median()
    .reset_index()
)

median_jobsat
# Out:
# /tmp/ipython-input-2135201587.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("ExperienceRange")["JobSat"]
#   ExperienceRange  JobSat
# 0       0–5 years     7.0
# 1      5–10 years     7.0
# 2     10–20 years     8.0
# 3       20+ years     8.0

# %% [markdown]
# #### Step 5: Visualize Job Satisfaction

# %% [markdown]
# Use a count plot to show the distribution of `JobSat` values. This provides insights into the overall satisfaction levels of respondents.

# %%
## Write your code here
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(
    median_jobsat["ExperienceRange"],
    median_jobsat["JobSat"]
)

plt.xlabel("Years of Professional Coding Experience")
plt.ylabel("Median Job Satisfaction")
plt.title("Median Job Satisfaction by Experience Level")
plt.show()

# %% [markdown]
# #### Step 6: Analyzing Remote Work Preferences by Job Role

# %% [markdown]
# Analyze trends in remote work based on job roles. Use the `RemoteWork` and `Employment` columns to explore preferences and examine if specific job roles prefer remote work more than others.
#
# - Use a count plot to show remote work distribution.
#
# - Cross-tabulate remote work preferences by employment type (e.g., full-time, part-time) and job roles.

# %%
## Write your code here

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Simplify Employment to avoid multi-category clutter
df["EmploymentSimple"] = df["Employment"].str.split(";").str[0]

# 2. Count plot: Remote work preferences by employment type
plt.figure(figsize=(20, 6))
sns.countplot(
    data=df,
    x="RemoteWork",
    hue="EmploymentSimple"
)
plt.title("Remote Work Preferences by Employment Type")
plt.xlabel("Remote Work Preference")
plt.ylabel("Count")
plt.legend(title="Employment Type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# 3. Cross-tabulation: counts
remote_crosstab = pd.crosstab(
    df["EmploymentSimple"],
    df["RemoteWork"]
)
remote_crosstab

# 4. Cross-tabulation: percentages (optional but useful)
remote_crosstab_pct = pd.crosstab(
    df["EmploymentSimple"],
    df["RemoteWork"],
    normalize="index"
) * 100
remote_crosstab_pct
# Out:
# RemoteWork                                          Hybrid (some remote, some in-person)  \
# EmploymentSimple
# Employed, full-time                                                            43.612520
# Employed, part-time                                                            50.932836
# Independent contractor, freelancer, or self-emp...                             32.601464
# Not employed, and not looking for work                                          0.000000
# Not employed, but looking for work                                             20.833333
# Student, full-time                                                             52.362949
# Student, part-time                                                             53.543307
#
# RemoteWork                                          In-person      Remote
# EmploymentSimple
# Employed, full-time                                 19.187221   37.200259
# Employed, part-time                                 18.656716   30.410448
# ...

# %%
# # Extra

# ## Write your code here
# df[["Employment", "RemoteWork"]].value_counts().head(10) # This gives a quick sense of the combinations in the data.
# df["EmploymentSimple"] = df["Employment"].str.split(";").str[0]

# # A count plot shows how frequently each remote work category appears.
# # What this shows:
# # - Overall popularity of Remote / Hybrid / In-person
# # - Helps identify the dominant remote work preference
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(8, 5))
# sns.countplot(
#     data=df,
#     x="RemoteWork"
# )

# plt.title("Distribution of Remote Work Preferences")
# plt.xlabel("Remote Work Preference")
# plt.ylabel("Count")
# plt.show()

# # Count plot by employment type (job role proxy)
# # Interpretation
# # - Compare full-time vs part-time vs self-employed
# # - See which employment types favor remote work more strongly

# # plt.figure(figsize=(10, 6))
# # sns.countplot(
# #     data=df,
# #     x="RemoteWork",
# #     hue="Employment"
# # )

# # plt.title("Remote Work Preferences by Employment Type")
# # plt.xlabel("Remote Work Preference")
# # plt.ylabel("Count")
# # plt.legend(title="Employment Type", bbox_to_anchor=(1.05, 1), loc="upper left")
# # plt.show()

# plt.figure(figsize=(10, 6))
# sns.countplot(
#     data=df,
#     x="RemoteWork",
#     hue="EmploymentSimple"
# )

# plt.title("Remote Work Preferences by Employment Type")
# plt.xlabel("Remote Work Preference")
# plt.ylabel("Count")
# plt.legend(title="Employment Type", bbox_to_anchor=(1.05, 1))
# plt.show()


# # Cross-tabulation: RemoteWork × Employment
# # This table answers:
# # - Do certain employment types prefer remote work more than others?
# remote_by_employment = pd.crosstab(
#     df["Employment"],
#     df["RemoteWork"]
# )

# remote_by_employment

# # Normalize to percentages (very useful)
# remote_by_employment_pct = pd.crosstab(
#     df["Employment"],
#     df["RemoteWork"],
#     normalize="index"
# ) * 100

# remote_by_employment_pct

# # Optional visualization of cross-tab (stacked bar)
# remote_by_employment_pct.plot(
#     kind="bar",
#     figsize=(10, 6)
# )

# plt.title("Remote Work Preferences by Employment Type (%)")
# plt.xlabel("Employment Type")
# plt.ylabel("Percentage")
# plt.legend(title="Remote Work Preference", bbox_to_anchor=(1.05, 1))
# plt.show()

# %% [markdown]
# #### Step 7: Analyzing Programming Language Trends by Region

# %% [markdown]
# Analyze the popularity of programming languages by region. Use the `LanguageHaveWorkedWith` column to investigate which languages are most used in different regions.
#
# - Filter data by country or region.
#
# - Visualize the top programming languages by region with a bar plot or heatmap.

# %%
## Write your code here


# =========================
# Step 7: Language Trends by Region (ALL IN ONE CELL)
# =========================
# df["Country"].unique()
df["Country"] = df["Country"].str.strip()
df["Country"].value_counts().head(20)

# 1) Choose regions (edit this list as you like)
regions = df["Country"].value_counts().head(5).index.tolist()

# 2) Filter to selected regions + keep rows with language info
df_region = df[df["Country"].isin(regions)].copy()
df_region = df_region.dropna(subset=["LanguageHaveWorkedWith"])

# 3) Split multi-value language column and explode into one language per row
df_region["Language"] = df_region["LanguageHaveWorkedWith"].str.split(";")
df_region = df_region.explode("Language")
df_region["Language"] = df_region["Language"].str.strip()

# 4) Count languages per region
lang_counts = (
    df_region.groupby(["Country", "Language"])
    .size()
    .reset_index(name="Count")
)

# 5) Bar plot: Top 5 languages per region
top_lang = (
    lang_counts.sort_values(["Country", "Count"], ascending=[True, False])
    .groupby("Country")
    .head(5)
)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_lang, x="Language", y="Count", hue="Country")
plt.title("Top Programming Languages by Region (Top 5 per Country)")
plt.xlabel("Programming Language")
plt.ylabel("Number of Developers")
plt.xticks(rotation=45)
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# 6) Heatmap: Top 10 languages overall (across selected regions)
pivot = pd.pivot_table(
    df_region,
    index="Language",
    columns="Country",
    aggfunc="size",
    fill_value=0
)

top10 = pivot.sum(axis=1).sort_values(ascending=False).head(10).index
pivot_top10 = pivot.loc[top10]

plt.figure(figsize=(10, 6))
sns.heatmap(pivot_top10, annot=True, fmt="d", cmap="Blues")
plt.title("Programming Language Usage by Region (Top 10 Overall)")
plt.xlabel("Country")
plt.ylabel("Programming Language")
plt.tight_layout()
plt.show()

# 7) Show tables (optional)
print("Top 5 languages per region:")
display(top_lang.sort_values(["Country", "Count"], ascending=[True, False]))

print("Heatmap table (Top 10 overall):")
display(pivot_top10)
# Out:
# Top 5 languages per region:
#                                                Country  \
# 22                                             Germany
# 36                                             Germany
# 19                                             Germany
# 40                                             Germany
# 3                                              Germany
# 71                                               India
# 68                                               India
# 89                                               India
# 85                                               India
# 93                                               India
# 120                                            Ukraine
# 138                                            Ukraine
# 117                                            Ukraine
# 142                                            Ukraine
# 134                                            Ukraine
# ...

# %% [markdown]
# #### Step 8: Correlation Between Experience and Satisfaction

# %% [markdown]
# Examine how years of experience (`YearsCodePro`) correlate with job satisfaction (`JobSatPoints_1`). Use a scatter plot to visualize this relationship.

# %%
## Write your code here

# 1️⃣ Prepare the data (clean + numeric)
# - YearsCodePro often contains strings, so we must clean it first.
# - JobSatPoints_1 is already numeric.

# Select YearsCodePro safely (now a Series in your cleaned dataset)
years = df["YearsCodePro"]

# Clean string values
years = years.replace({
    "Less than 1 year": 0,
    "More than 50 years": 50
})

# Convert to numeric
df["YearsCodePro_Clean"] = pd.to_numeric(years, errors="coerce")

# 2️⃣ Remove rows with missing values (important)
# For correlation and scatter plots, both variables must be present.
df_corr = df.dropna(subset=["YearsCodePro_Clean", "JobSatPoints_1"])

# 3️⃣ Scatter plot: Experience vs Job Satisfaction
plt.figure(figsize=(8, 5))

plt.scatter(
    df_corr["YearsCodePro_Clean"],
    df_corr["JobSatPoints_1"],
    alpha=0.5
)

plt.xlabel("Years of Professional Coding Experience")
plt.ylabel("Job Satisfaction Score (JobSatPoints_1)")
plt.title("Relationship Between Experience and Job Satisfaction")

plt.tight_layout()
plt.show()

# 4️⃣ (Self-added) Calculate correlation coefficient
correlation = df_corr["YearsCodePro_Clean"].corr(df_corr["JobSatPoints_1"])
correlation
# Out:
# np.float64(-0.03172178529759369)

# %% [markdown]
# 5️⃣ Explanation: A scatter plot was used to visualize the relationship between years of professional coding experience and job satisfaction. The points show a wide dispersion across all experience levels, indicating no clear trend. The calculated correlation coefficient (≈ −0.03) confirms that there is no significant linear relationship between experience and job satisfaction.

# %% [markdown]
# #### Step 9: Educational Background and Employment Type

# %% [markdown]
# Explore how educational background (`EdLevel`) relates to employment type (`Employment`). Use cross-tabulation and visualizations to understand if higher education correlates with specific employment types.

# %%
## Write your code here

# 1) Simplify Employment (multi-select -> take first item)
df["EmploymentSimple"] = df["Employment"].astype(str).str.split(";").str[0].str.strip()

# 2) Simplify EdLevel (optional but recommended to reduce long labels)
ed_map = {
    "Bachelor’s degree (B.A., B.S., B.Eng., etc.)": "Bachelor’s",
    "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": "Master’s",
    "Professional degree (JD, MD, etc.)": "Professional",
    "Doctoral degree (Ph.D., Ed.D., etc.)": "Doctorate",
    "Some college/university study without earning a degree": "Some college",
    "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": "Secondary school",
    "Primary/elementary school": "Primary school",
    "Associate degree (A.A., A.S., etc.)": "Associate",
    "Something else": "Other"
}
df["EdLevelSimple"] = df["EdLevel"].replace(ed_map)

# 3) Keep only rows where both variables exist
df_ed_emp = df.dropna(subset=["EdLevelSimple", "EmploymentSimple"]).copy()

# 4) Cross-tabulation (counts)
edu_emp_ct = pd.crosstab(df_ed_emp["EdLevelSimple"], df_ed_emp["EmploymentSimple"])
print("Cross-tab (Counts):")
display(edu_emp_ct)

# 5) Cross-tabulation (percentages by education level)
edu_emp_pct = pd.crosstab(
    df_ed_emp["EdLevelSimple"],
    df_ed_emp["EmploymentSimple"],
    normalize="index"
) * 100

print("Cross-tab (Percentages by EdLevel):")
display(edu_emp_pct.round(1))

# 6) Visualization: stacked bar chart of percentages
edu_emp_pct.plot(kind="bar", stacked=True, figsize=(12, 6))
plt.title("Employment Type by Educational Background (%)")
plt.xlabel("Education Level")
plt.ylabel("Percentage")
plt.legend(title="Employment Type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()
# Out:
# Cross-tab (Counts):
# EmploymentSimple                                Employed, full-time  \
# EdLevelSimple
# Associate                                                       817
# Bachelor’s                                                    12053
# Master’s                                                       7664
# Other                                                           260
# Primary school                                                  122
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                 1294
# Secondary school                                               1143
# Some college                                                   2878
#
# EmploymentSimple                                Employed, part-time  \
# EdLevelSimple
# Associate                                                        14
# Bachelor’s                                                      187
# Master’s                                                        170
# ...

# %% [markdown]
# #### Step 10: Save the Cleaned and Analyzed Dataset

# %% [markdown]
# After your analysis, save the modified dataset for further use or sharing.

# %%
## Write your code here
df.to_csv("cleaned_analyzed_dataset.csv", index=False)

# %%
df.to_excel("cleaned_analyzed_dataset.xlsx", index=False)

# %% [markdown]
# <h2>Summary</h2>

# %% [markdown]
# In this revised lab, you:
#
# - Loaded and explored the structure of the dataset.
#
# - Handled missing data effectively.
#
# - Analyzed key variables, including working hours, job satisfaction, and remote work trends.
#
# - Investigated programming language usage by region and examined the relationship between experience and satisfaction.
#
# - Used cross-tabulation to understand educational background and employment type.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Lab_11_Finding_How_The_Data_is_Distributed.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
## Write your code here

summary = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes,
    "Non-Null Count": df.count(),
    "Missing Values": df.isnull().sum()
})

summary
# Out:
#                              Column Name Data Type  Non-Null Count  \
# ResponseId                    ResponseId     int64           65437
# MainBranch                    MainBranch    object           65437
# Age                                  Age    object           65437
# Employment                    Employment    object           65437
# RemoteWork                    RemoteWork    object           54806
# ...                                  ...       ...             ...
# JobSatPoints_11          JobSatPoints_11   float64           29445
# SurveyLength                SurveyLength    object           56182
# SurveyEase                    SurveyEase    object           56238
# ConvertedCompYearly  ConvertedCompYearly   float64           23435
# JobSat                            JobSat   float64           29126
#
#                      Missing Values
# ResponseId                        0
# MainBranch                        0
# Age                               0
# ...

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
## Write your code here
# Identify missing values
missing_before = df.isnull().sum()

# Separate numerical and categorical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Impute missing values
df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].median())
df[categorical_cols] = df[categorical_cols].fillna("Unknown")

# Verify missing values after handling
missing_after = df.isnull().sum()

missing_before, missing_after
print("Missing values before handling:")
print(missing_before)
print("\nMissing values after handling:")
print(missing_after)
# Out:
# Missing values before handling:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64
#
# Missing values after handling:
# ResponseId             0
# MainBranch             0
# Age                    0
# Employment             0
# RemoteWork             0
#                       ..
# JobSatPoints_11        0
# SurveyLength           0
# SurveyEase             0
# ConvertedCompYearly    0
# JobSat                 0
# Length: 114, dtype: int64

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
## Write your code here
# Analyze key columns by calculating value counts

# employment_counts = df["Employment"].value_counts(dropna=False)
# jobsat_counts = df["JobSat"].value_counts(dropna=False)
# yearscodepro_counts = df["YearsCodePro"].value_counts(dropna=False)

# employment_counts, jobsat_counts, yearscodepro_counts

key_columns_summary = pd.concat(
    [
        df["Employment"].value_counts(dropna=False).reset_index(name="Employment_Count"),
        df["JobSat"].value_counts(dropna=False).reset_index(name="JobSat_Count"),
        df["YearsCodePro"].value_counts(dropna=False).reset_index(name="YearsCodePro_Count")
    ],
    axis=1
)

key_columns_summary
# Out:
#                                             Employment  Employment_Count  \
# 0                                  Employed, full-time             39041
# 1    Independent contractor, freelancer, or self-em...              4846
# 2                                   Student, full-time              4709
# 3    Employed, full-time;Independent contractor, fr...              3557
# 4                   Not employed, but looking for work              2341
# ..                                                 ...               ...
# 105  Not employed, but looking for work;Independent...                 1
# 106                         Student, full-time;Retired                 1
# 107  Employed, full-time;Not employed, but looking ...                 1
# 108  Not employed, and not looking for work;Student...                 1
# 109  Not employed, but looking for work;Independent...                 1
#
#      JobSat  JobSat_Count YearsCodePro  YearsCodePro_Count
# ...

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
## Write your code here

# Calculate value counts for JobSat
jobsat_counts = df["JobSat"].value_counts(dropna=False)

# Create pie chart
plt.figure(figsize=(7, 7))
wedges, texts, autotexts = plt.pie(
    jobsat_counts,
    autopct='%1.1f%%',
    startangle=140
)

# Add legend
plt.legend(
    wedges,
    jobsat_counts.index,
    title="Job Satisfaction Level",
    loc="best"
)

plt.title("Distribution of Job Satisfaction (JobSat)")
plt.axis('equal')
plt.show()


# Interpretation of Job Satisfaction Distribution
# The pie chart illustrates the distribution of job satisfaction levels among respondents. The largest portions of the chart correspond to respondents who report being satisfied or very satisfied, indicating an overall positive level of job satisfaction within the dataset.
# A smaller proportion of respondents fall into the neutral category, suggesting that some individuals neither feel strongly satisfied nor dissatisfied with their jobs. The dissatisfied and very dissatisfied categories represent the smallest segments, implying that relatively few respondents experience negative job satisfaction.
# Overall, the distribution suggests that job satisfaction is generally high, with positive responses significantly outweighing negative ones.

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# Answer:
#
# Comparison of Programming Language Frequencies
#
# The frequency comparison between LanguageHaveWorkedWith and LanguageWantToWorkWith shows both current usage patterns and future interest trends among respondents.
#
# Languages such as Python and JavaScript appear frequently in both categories, indicating they are widely used and continue to be highly desired skills.
#
# Some languages show higher counts in LanguageWantToWorkWith than in LanguageHaveWorkedWith, suggesting growing interest and potential emerging trends.
#
# Other languages have higher experience counts than interest counts, which may indicate mature technologies that respondents are less eager to focus on in the future.
#
# Overall, the comparison highlights a strong alignment between current experience and future aspirations, while also revealing shifts toward languages that respondents want to learn or use more extensively.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
## Write your code here

# Split and count languages
worked_with = (
    df["LanguageHaveWorkedWith"]
    .dropna()
    .str.split(";")
    .explode()
    .value_counts()
)

want_to_work = (
    df["LanguageWantToWorkWith"]
    .dropna()
    .str.split(";")
    .explode()
    .value_counts()
)

# Combine into a single DataFrame
language_comparison = pd.DataFrame({
    "Have Worked With": worked_with,
    "Want to Work With": want_to_work
}).fillna(0)

# Select top 10 languages by total interest
language_comparison["Total"] = (
    language_comparison["Have Worked With"] +
    language_comparison["Want to Work With"]
)

top_languages = (
    language_comparison
    .sort_values("Total", ascending=False)
    .head(10)
    .drop(columns="Total")
)

# Plot grouped bar chart
top_languages.plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Top 10 Programming Languages: Experience vs Interest")
plt.xlabel("Programming Language")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
## Write your code here

# Select relevant columns and drop missing values
remote_region = df[["Country", "RemoteWork"]].dropna()

# Group and count
remote_counts = (
    remote_region
    .groupby(["Country", "RemoteWork"])
    .size()
    .unstack(fill_value=0)
)

# Select top 10 countries by total responses
top_regions = remote_counts.sum(axis=1).sort_values(ascending=False).head(10).index
remote_counts_top = remote_counts.loc[top_regions]

# Plot grouped bar chart
remote_counts_top.plot(
    kind="bar",
    figsize=(14, 6)
)

plt.title("Remote Work Distribution by Region (Top 10 Countries)")
plt.xlabel("Region")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Remote Work Preference")
plt.tight_layout()
plt.show()

# %%
# Heat-Map Version:

# Select relevant columns and drop missing values
remote_region = df[["Country", "RemoteWork"]].dropna()

# Create contingency table
remote_pivot = (
    remote_region
    .groupby(["Country", "RemoteWork"])
    .size()
    .unstack(fill_value=0)
)

# Select top 10 countries by total responses
top_regions = remote_pivot.sum(axis=1).sort_values(ascending=False).head(10)
remote_pivot_top = remote_pivot.loc[top_regions.index]

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(
    remote_pivot_top,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Remote Work Distribution by Region (Top 10 Countries)")
plt.xlabel("Remote Work Preference")
plt.ylabel("Region")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# Answer:
# Correlation Analysis: Job Satisfaction vs. Professional Experience
#
# The correlation analysis between overall job satisfaction (JobSat) and years of professional coding experience (YearsCodePro) indicates a weak positive relationship between the two variables. This suggests that, in general, job satisfaction tends to increase slightly as professional experience increases, but the relationship is not strong.
#
# The weak correlation implies that while experience may contribute to job satisfaction, other factors—such as work environment, role expectations, compensation, and work-life balance—likely play a more significant role in determining how satisfied individuals feel in their jobs.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
## Write your code here
import pandas as pd

# Create clean working copy
temp = df[["JobSat", "YearsCodePro"]].copy()

# Normalize text
temp["JobSat"] = temp["JobSat"].astype(str).str.strip()
temp["YearsCodePro"] = temp["YearsCodePro"].astype(str).str.strip()

# Convert YearsCodePro to numeric
temp["YearsCodePro_Num"] = (
    temp["YearsCodePro"]
    .replace({"Less than 1 year": "0.5", "More than 50 years": "51"})
)
temp["YearsCodePro_Num"] = pd.to_numeric(
    temp["YearsCodePro_Num"], errors="coerce"
)

# Convert JobSat to categorical numeric codes
temp["JobSat_Cat"] = pd.Categorical(temp["JobSat"])
temp["JobSat_Num"] = temp["JobSat_Cat"].cat.codes.replace(-1, pd.NA)

# Keep only valid rows
temp = temp[["JobSat_Num", "YearsCodePro_Num"]].dropna()
print("Valid rows:", len(temp))

# Calculate Spearman correlation (ordinal-safe)
spearman_corr = (
    temp["JobSat_Num"].corr(temp["YearsCodePro_Num"], method="spearman")
    if len(temp) > 1 else None
)
# Pearson correlation
pearson_corr = temp["JobSat_Num"].corr(
    temp["YearsCodePro_Num"],
    method="pearson"
)

print("pearson_corr: ", pearson_corr)
print("spearman_corr: ", spearman_corr)
# Out:
# Valid rows: 51610
# pearson_corr:  0.01662688961170794
# spearman_corr:  0.05355359396475776

# %% [markdown]
# Self-Added
#
# Interpretation
#
# Both correlation coefficients indicate a very weak positive relationship between overall job satisfaction (JobSat) and years of professional coding experience (YearsCodePro).
#
# The Pearson correlation (r ≈ 0.02) suggests an almost negligible linear relationship between experience and job satisfaction.
#
# The Spearman correlation (ρ ≈ 0.05) indicates a slightly stronger but still very weak monotonic relationship, which is more appropriate given the ordinal nature of job satisfaction.
#
# Despite the large number of valid observations, the small magnitude of both coefficients shows that professional experience alone does not meaningfully predict job satisfaction. Other factors—such as work environment, compensation, role alignment, and work-life balance—likely play a much larger role.

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# Self-Added Answer:
#
# Relationship Between Employment Status and Education Level
#
# The cross-tabulation analysis reveals a clear association between employment status and education level among respondents.
#
# Full-time employment is most prevalent among individuals with bachelor’s and master’s degrees, indicating that higher education levels are strongly associated with stable, full-time roles.
#
# Respondents who are students are primarily concentrated in lower or in-progress education levels, such as secondary education or some college/university study without a completed degree.
#
# Part-time and other employment categories show a more mixed distribution of education levels, suggesting that education alone does not fully determine employment type.
#
# Advanced degrees (master’s and professional/doctoral degrees) appear less frequently in non-employment or part-time categories, reinforcing the link between higher education and full-time employment.
#
# Overall, the analysis suggests that education level influences employment status, but it is not the sole determining factor, as individuals with similar education levels can be found across multiple employment categories.
#
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
## Write your code here

# Create cross-tabulation
employment_education_ct = pd.crosstab(
    df["Employment"],
    df["EdLevel"]
)

# Display cross-tabulation
employment_education_ct

# Plot stacked bar chart
employment_education_ct.plot(
    kind="bar",
    stacked=True,
    figsize=(14, 6)
)

plt.title("Employment Status by Education Level")
plt.xlabel("Employment Status")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Education Level", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3921912667.py:24: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Option B much cleaner view:
# Create cross-tab
employment_education_ct = pd.crosstab(df["Employment"], df["EdLevel"])

# Keep top 5 employment categories
top_employment = employment_education_ct.sum(axis=1).sort_values(ascending=False).head(5).index
employment_education_top = employment_education_ct.loc[top_employment]

# Plot
employment_education_top.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6)
)

plt.title("Employment Status by Education Level (Top Employment Categories)")
plt.xlabel("Employment Status")
plt.ylabel("Number of Respondents")
plt.xticks(rotation=30, ha="right")
plt.legend(title="Education Level", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
## Write your code here
# Save the cleaned dataset to a new CSV file
df.to_csv("cleaned_survey_data.csv", index=False)

print("Cleaned dataset saved successfully as 'cleaned_survey_data.csv'")
# Out:
# Cleaned dataset saved successfully as 'cleaned_survey_data.csv'

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Lab_12_Finding_Outliers.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Outliers**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform exploratory data analysis or EDA.
# You will explore the distribution of key variables and focus on identifying outliers in this lab.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -  Analyze the distribution of key variables in the dataset.
#
# -  Identify and remove outliers using statistical methods.
#
# -  Perform relevant statistical and correlation analysis.

# %% [markdown]
# #### Install and import the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Step 1: Load and Explore the Dataset</h3>

# %% [markdown]
# Load the dataset into a DataFrame and examine the structure of the data.

# %%
file_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

#Create the dataframe
df = pd.read_csv(file_url)

#Display the top 10 records
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# <h3>Step 2: Plot the Distribution of Industry</h3>

# %% [markdown]
# Explore how respondents are distributed across different industries.
#
# - Plot a bar chart to visualize the distribution of respondents by industry.
#
# - Highlight any notable trends.
#
# Answer:
#
# Notable Trends in Industry Distribution
#
# Strong dominance of Software Development
#
# Software Development has an overwhelmingly higher number of respondents compared to all other industries.
#
# This indicates the survey is primarily representative of software professionals, which may bias insights toward software-centric roles and perspectives.
#
# Large “Other” category
#
# The “Other” industry group is the second-largest segment, suggesting that:
#
# Many respondents work in industries not explicitly listed
#
# Industry classification may be too broad or incomplete
#
# Tech-adjacent industries form a clear secondary cluster
#
# Fintech, Internet/Telecom/Information Services, and Banking/Financial Services show similar and moderately high participation.
#
# This reflects the growing integration of software development within financial and digital service sectors.
#
# Balanced mid-tier industries
#
# Healthcare, Manufacturing, Retail & Consumer Services, and Government have steady but lower representation.
#
# This suggests increasing adoption of technical roles across traditional industries, though not at the same scale as pure software companies.
#
# Underrepresentation of certain sectors
#
# Energy and Insurance have the lowest number of respondents, indicating either:
#
# Smaller tech workforces
#
# Lower engagement with developer-focused surveys
#
# Summary Insight (One-Line Conclusion)
#
# The dataset is heavily skewed toward software-related roles, with diminishing representation as industries move further away from core technology sectors.

# %%
##Write your code here

# Count respondents per industry
industry_counts = df['Industry'].value_counts()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(
    x=industry_counts.values,
    y=industry_counts.index
)

plt.title('Distribution of Respondents by Industry')
plt.xlabel('Number of Respondents')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Step 3: Identify High Compensation Outliers</h3>

# %% [markdown]
# Identify respondents with extremely high yearly compensation.
#
# - Calculate basic statistics (mean, median, and standard deviation) for `ConvertedCompYearly`.
#
# - Identify compensation values exceeding a defined threshold (e.g., 3 standard deviations above the mean).

# %%
##Write your code here

# Drop missing compensation values
comp = df['ConvertedCompYearly'].dropna()

# Calculate basic statistics
mean_comp = comp.mean()
median_comp = comp.median()
std_comp = comp.std()

# Define outlier threshold (3 standard deviations above the mean)
threshold = mean_comp + 3 * std_comp

# Identify respondents exceeding the threshold
high_comp_outliers = df[df['ConvertedCompYearly'] > threshold]

# Display results
print(f"Mean: {mean_comp:,.0f}")
print(f"Median: {median_comp:,.0f}")
print(f"Standard Deviation: {std_comp:,.0f}")
print(f"Outlier Threshold (Mean + 3*STD): {threshold:,.0f}")
print(f"Number of High-Compensation Outliers: {high_comp_outliers.shape[0]}")

# Show top 10 extreme values
high_comp_outliers[['ConvertedCompYearly', 'Industry', 'Country']] \
    .sort_values(by='ConvertedCompYearly', ascending=False) \
    .head(10)
# Out:
# Mean: 86,155
# Median: 65,000
# Standard Deviation: 186,757
# Outlier Threshold (Mean + 3*STD): 646,426
# Number of High-Compensation Outliers: 89
#        ConvertedCompYearly                              Industry       Country
# 15837           16256603.0                                   NaN      Ethiopia
# 12723           13818022.0          Media & Advertising Services  South Africa
# 28379            9000000.0  Computer Systems Design and Services        Taiwan
# 17593            6340564.0                  Software Development        Brazil
# 17672            4936778.0                  Software Development       Ukraine
# 19267            3367716.0                                Other:         India
# 23694            2584118.0                                   NaN      Pakistan
# 33720            2237846.0                                   NaN        Brazil
# 34523            2153432.0                  Software Development      Pakistan
# ...

# %% [markdown]
# <h3>Step 4: Detect Outliers in Compensation</h3>

# %% [markdown]
# Identify outliers in the `ConvertedCompYearly` column using the IQR method.
#
# - Calculate the Interquartile Range (IQR).
#
# - Determine the upper and lower bounds for outliers.
#
# - Count and visualize outliers using a box plot.

# %%
##Write your code here

# Drop missing values
comp = df['ConvertedCompYearly'].dropna()

# Calculate quartiles
Q1 = comp.quantile(0.25)
Q3 = comp.quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Determine outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
iqr_outliers = df[
    (df['ConvertedCompYearly'] < lower_bound) |
    (df['ConvertedCompYearly'] > upper_bound)
]

# Print results
print(f"Q1: {Q1:,.0f}")
print(f"Q3: {Q3:,.0f}")
print(f"IQR: {IQR:,.0f}")
print(f"Lower Bound: {lower_bound:,.0f}")
print(f"Upper Bound: {upper_bound:,.0f}")
print(f"Number of IQR Outliers: {iqr_outliers.shape[0]}")

# Box plot visualization
plt.figure(figsize=(10, 4))
sns.boxplot(x=comp)
plt.title('Box Plot of Yearly Compensation (ConvertedCompYearly)')
plt.xlabel('Yearly Compensation')
plt.show()
# Out:
# Q1: 32,712
# Q3: 107,972
# IQR: 75,260
# Lower Bound: -80,177
# Upper Bound: 220,861
# Number of IQR Outliers: 978

# %% [markdown]
# <h3>Step 5: Remove Outliers and Create a New DataFrame</h3>

# %% [markdown]
# Remove outliers from the dataset.
#
# - Create a new DataFrame excluding rows with outliers in `ConvertedCompYearly`.
# - Validate the size of the new DataFrame.

# %%
##Write your code here
# Drop missing values only for compensation filtering
comp = df['ConvertedCompYearly'].dropna()

# Recalculate IQR bounds (or reuse previous values if already defined)
Q1 = comp.quantile(0.25)
Q3 = comp.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create new DataFrame excluding outliers
df_no_outliers = df[
    (df['ConvertedCompYearly'].isna()) |  # keep rows without compensation
    ((df['ConvertedCompYearly'] >= lower_bound) &
     (df['ConvertedCompYearly'] <= upper_bound))
]

# Validate sizes
print(f"Original DataFrame size: {df.shape}")
print(f"New DataFrame size (outliers removed): {df_no_outliers.shape}")
print(f"Number of rows removed: {df.shape[0] - df_no_outliers.shape[0]}")
# Out:
# Original DataFrame size: (65437, 114)
# New DataFrame size (outliers removed): (64459, 114)
# Number of rows removed: 978

# %% [markdown]
# <h3>Step 6: Correlation Analysis</h3>

# %% [markdown]
# Analyze the correlation between `Age` (transformed) and other numerical columns.
#
# - Map the `Age` column to approximate numeric values.
#
# - Compute correlations between `Age` and other numeric variables.
#
# - Visualize the correlation matrix.

# %%
##Write your code here
import numpy as np

# 1️⃣ Map Age ranges to approximate numeric values
age_mapping = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 30,
    '35-44 years old': 40,
    '45-54 years old': 50,
    '55-64 years old': 60,
    '65 years or older': 70
}

df['Age_numeric'] = df['Age'].map(age_mapping)

# 2️⃣ Select numerical columns (including transformed Age)
numeric_cols = df.select_dtypes(include=[np.number])

# Compute correlation matrix
corr_matrix = numeric_cols.corr()

# Show correlations with Age
print("Correlation with Age:\n")
print(corr_matrix['Age_numeric'].sort_values(ascending=False))

# 3️⃣ Visualize correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    annot=False,
    linewidths=0.5
)

plt.title('Correlation Matrix of Numerical Variables (Including Age)')
plt.show()
# Out:
# Correlation with Age:
#
# Age_numeric            1.000000
# WorkExp                0.848803
# ConvertedCompYearly    0.122133
# JobSat                 0.069818
# CompTotal             -0.002698
# JobSatPoints_1        -0.027675
# ResponseId            -0.038245
# JobSatPoints_8        -0.046204
# JobSatPoints_6        -0.050017
# JobSatPoints_4        -0.076150
# JobSatPoints_9        -0.081759
# JobSatPoints_7        -0.083232
# JobSatPoints_5        -0.101560
# JobSatPoints_11       -0.107170
# JobSatPoints_10       -0.114571
# Name: Age_numeric, dtype: float64

# %% [markdown]
# <h3> Summary </h3>

# %% [markdown]
# In this lab, you developed essential skills in **Exploratory Data Analysis (EDA)** with a focus on outlier detection and removal. Specifically, you:

# %% [markdown]
# - Loaded and explored the dataset to understand its structure.
#
# - Analyzed the distribution of respondents across industries.
#
# - Identified and removed high compensation outliers using statistical thresholds and the Interquartile Range (IQR) method.
#
# - Performed correlation analysis, including transforming the `Age` column into numeric values for better analysis.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-1|1.1|Madhusudan Moole|Reviewed and updated lab|
# |2024-09-29|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Lab_13_Finding_Correlation.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Correlation**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform exploratory data analysis (EDA). You will examine the distribution of the data, identify outliers, and determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Identify the distribution of compensation data in the dataset.
#
# - Remove outliers to refine the dataset.
#
# - Identify correlations between various features in the dataset.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# ##### Step 1: Install and Import Required Libraries

# %%
# Install the necessary libraries
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
# Load the dataset from the given URL
file_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(file_url)

# Display the first few rows to understand the structure of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# <h3>Step 3: Analyze and Visualize Compensation Distribution</h3>

# %% [markdown]
# **Task**: Plot the distribution and histogram for `ConvertedCompYearly` to examine the spread of yearly compensation among respondents.

# %%
## Write your code here

# Prepare the data: remove missing and non-positive values
comp_data = df['ConvertedCompYearly'].dropna()
comp_data = comp_data[comp_data > 0]

# Create histogram
plt.figure(figsize=(10, 6))
plt.hist(comp_data, bins=50)
plt.xlabel('Yearly Compensation (ConvertedCompYearly)')
plt.ylabel('Number of Respondents')
plt.title('Distribution of Yearly Compensation')
plt.show()

# Create log-scaled histogram
plt.figure(figsize=(10, 6))
plt.hist(comp_data, bins=50)
plt.xscale('log')
plt.xlabel('Yearly Compensation (Log Scale)')
plt.ylabel('Number of Respondents')
plt.title('Distribution of Yearly Compensation (Log Scale)')
plt.show()

# %% [markdown]
# <h3>Step 4: Calculate Median Compensation for Full-Time Employees</h3>

# %% [markdown]
# **Task**: Filter the data to calculate the median compensation for respondents whose employment status is "Employed, full-time."

# %%
## Write your code here

# Filter data for full-time employed respondents
full_time_df = df[df['Employment'] == 'Employed, full-time']

# Drop missing and non-positive compensation values
full_time_comp = full_time_df['ConvertedCompYearly'].dropna()
full_time_comp = full_time_comp[full_time_comp > 0]

# Calculate median compensation
median_full_time_comp = full_time_comp.median()

print("Median Yearly Compensation for Full-Time Employees:", median_full_time_comp)
# Out:
# Median Yearly Compensation for Full-Time Employees: 69814.0

# %% [markdown]
# <h3>Step 5: Analyzing Compensation Range and Distribution by Country</h3>

# %% [markdown]
# Explore the range of compensation in the ConvertedCompYearly column by analyzing differences across countries. Use box plots to compare the compensation distributions for each country to identify variations and anomalies within each region, providing insights into global compensation trends.

# %%
## Write your code here

# Remove rows with missing compensation or country
comp_df = df[['Country', 'ConvertedCompYearly']].dropna()

# Select top 10 countries by number of respondents
top_countries = comp_df['Country'].value_counts().head(10).index
comp_df = comp_df[comp_df['Country'].isin(top_countries)]

# Create box plot
# plt.figure(figsize=(20, 6))
plt.figure(figsize=(20, 6))
sns.boxplot(
    data=comp_df,
    x='Country',
    y='ConvertedCompYearly'
)

plt.title('Compensation Distribution by Country')
plt.xlabel('Country')
plt.ylabel('Yearly Compensation (USD)')
plt.yscale('log') # modifies the existing y-axis (Apply a log scale to handle extreme salary values)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h3>Step 6: Removing Outliers from the Dataset</h3>

# %% [markdown]
# **Task**: Create a new DataFrame by removing outliers from the `ConvertedCompYearly` column to get a refined dataset for correlation analysis.

# %%
## Write your code here

# Calculate Q1, Q3, and IQR
Q1 = df['ConvertedCompYearly'].quantile(0.25)
Q3 = df['ConvertedCompYearly'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create a new DataFrame without outliers
df_refined = df[
    (df['ConvertedCompYearly'] >= lower_bound) &
    (df['ConvertedCompYearly'] <= upper_bound)
]

# Validate the result
print("Original dataset size:", df.shape)
print("Refined dataset size:", df_refined.shape)
# Out:
# Original dataset size: (65437, 114)
# Refined dataset size: (22457, 114)

# %% [markdown]
# <h3>Step 7: Finding Correlations Between Key Variables</h3>

# %% [markdown]
# **Task**: Calculate correlations between `ConvertedCompYearly`, `WorkExp`, and `JobSatPoints_1`. Visualize these correlations with a heatmap.

# %%
## Write your code here

# Select relevant columns from the refined dataset
corr_df = df_refined[['ConvertedCompYearly', 'WorkExp', 'JobSatPoints_1']].dropna()

# Compute correlation matrix
corr_matrix = corr_df.corr()

# Visualize correlations using a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Between Compensation, Work Experience, and Job Satisfaction')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Step 8: Scatter Plot for Correlations</h3>

# %% [markdown]
# **Task**: Create scatter plots to examine specific correlations between `ConvertedCompYearly` and `WorkExp`, as well as between `ConvertedCompYearly` and `JobSatPoints_1`.

# %%
## Write your code here

# Scatter plot: Compensation vs Work Experience
plt.figure(figsize=(7, 5))
sns.scatterplot(
    data=df_refined,
    x='WorkExp',
    y='ConvertedCompYearly',
    alpha=0.6
)

plt.yscale('log')
plt.title('Compensation vs Work Experience')
plt.xlabel('Work Experience (Years)')
plt.ylabel('Yearly Compensation (USD)')
plt.tight_layout()
plt.show()

# Scatter plot: Compensation vs Job Satisfaction
plt.figure(figsize=(7, 5))
sns.scatterplot(
    data=df_refined,
    x='JobSatPoints_1',
    y='ConvertedCompYearly',
    alpha=0.6
)

plt.yscale('log')
plt.title('Compensation vs Job Satisfaction')
plt.xlabel('Job Satisfaction Score')
plt.ylabel('Yearly Compensation (USD)')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Summary</h3>

# %% [markdown]
# In this lab, you practiced essential skills in correlation analysis by:
#
# - Examining the distribution of yearly compensation with histograms and box plots.
# - Detecting and removing outliers from compensation data.
# - Calculating correlations between key variables such as compensation, work experience, and job satisfaction.
# - Visualizing relationships with scatter plots and heatmaps to gain insights into the associations between these features.
#
# By following these steps, you have developed a solid foundation for analyzing relationships within the dataset.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_Finding_Duplicates_v2.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")
len(df)
# Out:
# 65457

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
duplicates = df[df.duplicated()] # From the DataFrame df, select only the rows that are duplicates, and store them in duplicates.
print(duplicates.shape[0]) # same as: print(len(duplicates)) (returns the number of rows)
duplicates.head()
# Out:
# 20
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
subset_duplicates = df[df.duplicated( # From the DataFrame df, select only the rows that are duplicates considering just these 3 coloumns, and store them in subset_duplicates.
    subset=['MainBranch', 'Employment', 'RemoteWork'],
    keep=False
)]
print(subset_duplicates.shape[0])
subset_duplicates.head(50)

# len(subset_duplicates[['MainBranch', 'Employment', 'RemoteWork']].value_counts())
# subset_duplicates[['MainBranch', 'Employment', 'RemoteWork']].value_counts()

# subset_duplicates.MainBranch.value_counts()  # L1
subset_duplicates.Employment.value_counts()  # L2
# subset_duplicates.RemoteWork.value_counts()  # L3

# The column 'MainBranch' mostly contains identical value of 'I am a developer by
# profession' (50173 rows. running Line L1) meaning most of the survay applicants have been professional developers.
# The column 'Employment' (39048 rows. running L2) mostly contains 'Employed, full-time' meaning most of
# the survay applicants have been full-time employees.
# Out:
# 65290
# Employment
# Employed, full-time                                                                                                                                                       39048
# Independent contractor, freelancer, or self-employed                                                                                                                       4845
# Student, full-time                                                                                                                                                         4713
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                   3558
# Not employed, but looking for work                                                                                                                                         2341
# ...

# %%
# This cell is added by my own (not needed for the lab)

subset_duplicates.info(verbose=False) # the verbose=False parameter instructs pandas to display a concise summary of the DataFrame rather than a detailed one
subset_duplicates.describe()
subset_duplicates.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65290 entries, 0 to 65456
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 57.3+ MB
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10600
#                        ...
# JobSatPoints_11        35876
# SurveyLength            9219
# SurveyEase              9162
# ConvertedCompYearly    41870
# JobSat                 36195
# Length: 114, dtype: int64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
import seaborn as sns

# Group by Country and Employment and count occurrences
grouped_dups = duplicates.groupby(['Country', 'Employment']).size().reset_index(name='DuplicateCount')
# print("\nGrouped Duplicates:\n", grouped_dups)
plt.figure(figsize=(20, 6))

grouped_dups.plot(kind='barh', x='Country', y='DuplicateCount',  figsize=(20, 6))
plt.title('Number of Duplicates by Country and Employment Type')
plt.ylabel('Country')
plt.xlabel('Count of Duplicates')
plt.show()

# sns.barplot(data=grouped_dups, x='DuplicateCount', y='Country', hue='Employment')
# plt.title('Number of Duplicates by Country and Employment Type')
# plt.ylabel('Country')
# plt.xlabel('Count of Duplicates')
# plt.show()

emp_type_dups = duplicates['Employment'].value_counts()

plt.figure(figsize=(7, 7))
plt.pie(emp_type_dups, labels=emp_type_dups.index, autopct='%1.1f%%',
        startangle=90, pctdistance=0.85, colors=sns.color_palette('pastel'))

# Draw a white circle in the middle to create the Donut Chart
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Proportion of Duplicates by Employment Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
# 1. Defining Uniqueness
# In this dataset, each row represents a developer respondent, but many columns (e.g., learning resources, documentation usage, or years of experience) vary and should not be used to define duplicates.
# To identify meaningful duplicates, uniqueness was defined using core demographic and professional attributes that best describe an individual’s profile:
      # Country – geographic context
      # Employment – employment status
      # DevType – professional role
      # Age – demographic identifier
# These columns collectively capture the essential identity of a respondent while excluding noisy or highly variable fields.


# 2. Removing Duplicates Strategically
# Rather than removing only exact row duplicates, duplicates were identified based on the selected subset of columns.
# To preserve the most informative record, the row with the highest professional experience (YearsCodePro) was retained.

# Sort to keep the most experienced respondent per profile
df_sorted = df.sort_values("YearsCodePro", ascending=False)

# Remove duplicates based on selected key columns
df_clean = df_sorted.drop_duplicates(
    subset=["Country", "Employment", "DevType", "Age"],
    keep="first"
)

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Step 1: Initial Duplicate Assessment
#
# The dataset was first examined for exact row-level duplication. Given the diversity of columns (demographics, learning preferences, tools, and experience), complete row duplication was determined to be an unreliable criterion for identifying true duplicates.
#
# Step 2: Defining Logical Uniqueness
#
# To identify meaningful duplicates, a subset of columns representing core respondent characteristics was selected:
#
# Country
#
# Employment
#
# DevType
#
# Age
#
# These fields collectively describe a respondent’s demographic and professional profile while excluding high-variability or free-text columns.
#
# Step 3: Duplicate Detection
#
# Duplicates were identified using the selected subset of columns rather than the entire row. This allowed the detection of respondents with identical profiles but differing secondary attributes.
#
# Step 4: Retention Strategy
#
# When duplicates were identified, the record with the highest professional experience (YearsCodePro) was retained. This ensured that the most informative and representative entry was preserved.
#
# Step 5: Duplicate Removal Implementation
#
# The dataset was sorted by professional experience and duplicates were removed based on the defined subset:
#
# df_sorted = df.sort_values("YearsCodePro", ascending=False)
#
# df_clean = df_sorted.drop_duplicates(
#     subset=["Country", "Employment", "DevType", "Age"],
#     keep="first"
# )
#
# Step 6: Validation
#
# The dataset size was compared before and after duplicate removal to confirm the operation’s impact, and a follow-up check verified that no duplicate profiles remained.
#
# Outcome
#
# This strategic approach reduced redundancy without removing valuable information, resulting in a cleaner dataset suitable for reliable exploratory data analysis and modeling.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and
#
# ---
#
# removing duplicates.

# %% [raw]
# # Write your explanation here
# The goal of duplicate removal in this dataset was to eliminate redundant records without discarding meaningful information. Rather than relying on full-row duplication, which is too restrictive for survey-style data, a subset of columns was chosen to define logical uniqueness.
#
# Selected Columns and Rationale
#
# Country
# Provides geographic context and helps distinguish respondents from different regions.
#
# Employment
# Captures the respondent’s employment status, a stable attribute that significantly differentiates profiles.
#
# DevType
# Represents the respondent’s professional role and is central to most analytical objectives in a developer-focused dataset.
#
# Age
# Adds a demographic dimension that helps differentiate individuals with otherwise similar professional characteristics.
#
# Why Other Columns Were Excluded
#
# Many columns were intentionally excluded from the uniqueness criteria because they are:
#
# Highly variable (e.g., learning resources, documentation usage)
#
# Free-text or multi-select (e.g., LearnCode, TechDoc)
#
# Experience-based or time-dependent (e.g., YearsCode, YearsCodePro)
#
# Including these columns would prevent the detection of meaningful duplicates and could incorrectly treat similar respondents as unique.
#
# Overall Justification
#
# The selected columns strike a balance between:
#
# Precision – accurately identifying duplicate respondent profiles
#
# Flexibility – allowing legitimate variation in learning behavior and experience
#
# Data integrity – avoiding unnecessary loss of valuable information
#
# This approach ensures that duplicate removal supports reliable exploratory data analysis and downstream modeling.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_7_Removing_Duplicates_v2.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Removing Duplicates**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will focus on data wrangling, an important step in preparing data for analysis. Data wrangling involves cleaning and organizing data to make it suitable for analysis. One key task in this process is removing duplicate entries, which are repeated entries that can distort analysis and lead to inaccurate conclusions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows  in the dataset.
# 2. Use suitable techniques to remove duplicate rows and verify the removal.
# 3. Summarize how to handle missing values appropriately.
# 4. Use ConvertedCompYearly to normalize compensation data.

# %% [markdown]
# ### Install the Required Libraries

# %%
# !pip install pandas

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2: Load the Dataset into a DataFrame

# %% [markdown]
# load the dataset using pd.read_csv()

# %%
# Define the URL of the dataset
# file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"  # added by myself


# Load the dataset into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# **Note: If you are working on a local Jupyter environment, you can use the URL directly in the <code>pandas.read_csv()</code>  function as shown below:**

# %% [markdown]
# #df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ### Step 3: Identifying Duplicate Rows

# %% [markdown]
# **Task 1: Identify Duplicate Rows**
#   1. Count the number of duplicate rows in the dataset.
#   2. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
duplicates = df[df.duplicated()] # From the DataFrame df, select only the rows that are duplicates, and store them in duplicates.
print(duplicates.shape[0]) # same as: print(len(duplicates)) (returns the number of rows)
duplicates.head()
# Out:
# 20
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Step 4: Removing Duplicate Rows

# %% [markdown]
# **Task 2: Remove Duplicates**
#    1. Remove duplicate rows from the dataset using the drop_duplicates() function.
# 2. Verify the removal by counting the number of duplicate rows after removal .

# %%
## Write your code here
df = df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Step 5: Handling Missing Values

# %% [markdown]
# **Task 3: Identify and Handle Missing Values**
#    1. Identify missing values for all columns in the dataset.
#    2. Choose a column with significant missing values (e.g., EdLevel) and impute with the most frequent value.

# %%
## Write your code here
missing_values = df.isnull().sum() # This line identifies missing values in the dataset by counting the number of null entries in each column.
print(missing_values)
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# ### Step 6: Normalizing Compensation Data

# %% [markdown]
# **Task 4: Normalize Compensation Data Using ConvertedCompYearly**
#    1. Use the ConvertedCompYearly column for compensation analysis as the normalized annual compensation is already provided.
#    2. Check for missing values in ConvertedCompYearly and handle them if necessary.

# %%
## Write your code here
df["ConvertedCompYearly"].isnull().sum()
df_comp = df.dropna(subset=["ConvertedCompYearly"])
df_comp["ConvertedCompYearly"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 7: Summary and Next Steps

# %% [markdown]
# **In this lab, you focused on identifying and removing duplicate rows.**
#
# - You handled missing values by imputing the most frequent value in a chosen column.
#
# - You used ConvertedCompYearly for compensation normalization and handled missing values.
#
# - For further analysis, consider exploring other columns or visualizing the cleaned dataset.

# %%
## Write your code here
# df_comp.head()

# %% [markdown]
# <!--
# ## Change Log
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
#
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_8_Finding_Missing_Values.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Missing Values**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# Data wrangling is the process of cleaning, transforming, and organizing data to make it suitable for analysis. Finding and handling missing values is a crucial step in this process to ensure data accuracy and completeness. In this lab, you will focus exclusively on identifying and handling missing values in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Identify missing values in the dataset.
#
# - Quantify missing values for specific columns.
#
# - Impute missing values using various strategies.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# ##### Setup: Install Required Libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ##### Import Necessary Modules:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tasks

# %% [markdown]
# <h2>1. Load the Dataset</h2>
# <p>
# We use the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Define the URL of the dataset
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

# Load the dataset into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
df.head()
# print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### 2. Explore the Dataset
# ##### Task 1: Display basic information and summary statistics of the dataset.

# %%
## Write your code here
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %% [markdown]
# ### 3. Finding Missing Values
# ##### Task 2: Identify missing values for all columns.

# %%
## Write your code here
df_missing = df.isnull().sum()
df_missing
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# ##### Task 3: Visualize missing values using a heatmap (Using seaborn library).

# %%
## Write your code here
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Heatmap of Missing Values")
plt.show()

# plt.figure(figsize=(12, 6))
# sns.heatmap(df.isnull(), cbar=False, yticklabels=False)
# plt.title("Heatmap of Missing Values")
# plt.show()

# %% [markdown]
# ##### Task 4: Count the number of missing rows for a specific column (e.g., `Employment`).

# %%
## Write your code here
df.Employment.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 4. Imputing Missing Values
# ##### Task 5: Identify the most frequent (majority) value in a specific column (e.g., `Employment`).

# %%
## Write your code here
df.Employment.value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                                   39041
# Independent contractor, freelancer, or self-employed                                                                                                   4846
# Student, full-time                                                                                                                                     4709
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                               3557
# Not employed, but looking for work                                                                                                                     2341
#                                                                                                                                                       ...
# ...

# %% [markdown]
# ##### Task 6: Impute missing values in the `Employment` column with the most frequent value.

# %%
## Write your code here
# df.Employment.fillna("Employed full-time", inplace=True)
df["Employment"] = df["Employment"].fillna("Employed full-time")

# %% [markdown]
# ### 5. Visualizing Imputed Data
# ##### Task 7: Visualize the distribution of a column after imputation (e.g., `Employment`).

# %%
## Write your code here
# plt.figure(figsize=(12, 6))
# sns.countplot(data=df, x="Employment")

plt.figure(figsize=(10, 6))
sns.countplot(y="Employment", data=df)
plt.title("Distribution of Employment After Imputation")
plt.xlabel("Count")
plt.ylabel("Employment")
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
# - Loaded the dataset into a pandas DataFrame.
# - Identified missing values across all columns.
# - Quantified missing values in specific columns.
# - Imputed missing values in a categorical column using the most frequent value.
# - Visualized the imputed data for better understanding.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_9_Imput_Missing_Values.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Impute Missing Values**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will practice essential data wrangling techniques using the Stack Overflow survey dataset. The primary focus is on handling missing data and ensuring data quality. You will:
#
# - **Load the Data:** Import the dataset into a DataFrame using the pandas library.
#
# - **Clean the Data:** Identify and remove duplicate entries to maintain data integrity.
#
# - **Handle Missing Values:** Detect missing values, impute them with appropriate strategies, and verify the imputation to create a complete and reliable dataset for analysis.
#
# This lab equips you with the skills to effectively preprocess and clean real-world datasets, a crucial step in any data analysis project.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Identify missing values in the dataset.
#
# -   Apply techniques to impute missing values in the dataset.
#
# -   Use suitable techniques to normalize data in the dataset.

# %% [markdown]
# -----

# %% [markdown]
# #### Install needed library

# %%
# !pip install pandas

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2: Load the Dataset Into a Dataframe

# %% [markdown]
# #### **Read Data**
# <p>
# The functions below will download the dataset into your browser:
# </p>

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 3. Finding and Removing Duplicates
# ##### Task 1: Identify duplicate rows in the dataset.

# %%
## Write your code here
# duplicates = df.isnull().sum()
# print(duplicates.shape[0]) # same as: print(len(duplicates)) (returns the number of rows)
# duplicates

duplicates = df[df.duplicated()] # From the DataFrame df, select only the rows that are duplicates, and store them in duplicates.
print(duplicates.shape[0]) # same as: print(len(duplicates)) (returns the number of rows)
duplicates.head()
# Out:
# 0
# Empty DataFrame
# ...

# %% [markdown]
# ##### Task 2: Remove the duplicate rows from the dataframe.

# %%
## Write your code here)
df = df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Step 4: Finding Missing Values
# ##### Task 3: Find the missing values for all columns.

# %%
## Write your code here
# df_missing = df.isnull()
# df_missing.head(10)

df_missing = df.isnull().sum() # This line identifies missing values in the dataset by counting the number of null entries in each column.
df_missing.head(10)
# Out:
# ResponseId              0
# MainBranch              0
# Age                     0
# Employment              0
# RemoteWork          10631
# Check                   0
# CodingActivities    10971
# EdLevel              4653
# LearnCode            4949
# LearnCodeOnline     16200
# dtype: int64

# %% [markdown]
# ##### Task 4: Find out how many rows are missing in the column RemoteWork.

# %%
## Write your code here
print(df.RemoteWork.isnull().sum())
# Out:
# 10631

# %% [markdown]
# ### Step 5. Imputing Missing Values
# ##### Task 5: Find the value counts for the column RemoteWork.

# %%
## Write your code here
df["RemoteWork"].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %% [markdown]
# ##### Task 6: Identify the most frequent (majority) value in the RemoteWork column.

# %%
## Write your code here
df["RemoteWork"].mode()[0]
# or:
# df["RemoteWork"].mode()
# Out:
# 'Hybrid (some remote, some in-person)'

# %% [markdown]
# ##### Task 7: Impute (replace) all the empty rows in the column RemoteWork with the majority value.

# %%
## Write your code here
df['RemoteWork'] = df['RemoteWork'].fillna(df['RemoteWork'].mode()[0])
# df['RemoteWork'].fillna(df['RemoteWork'].mode([0]))

# %% [markdown]
# ##### Task 8: Check for any compensation-related columns and describe their distribution.

# %%
## Write your code here

# Answer: The dataset contains one compensation-related column, ConvertedCompYearly, which represents normalized annual compensation.
df["ConvertedCompYearly"].describe()
# Out:
# count    2.343500e+04
# mean     8.615529e+04
# std      1.867570e+05
# min      1.000000e+00
# 25%      3.271200e+04
# 50%      6.500000e+04
# 75%      1.079715e+05
# max      1.625660e+07
# Name: ConvertedCompYearly, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Visualization:
plt.figure(figsize=(8, 5))
sns.histplot(df["ConvertedCompYearly"].dropna(), bins=50)
plt.title("Distribution of Annual Compensation")
plt.xlabel("Annual Compensation")
plt.ylabel("Frequency")
plt.show()

# The ConvertedCompYearly column shows a highly right-skewed distribution. While
# the median annual compensation is $65,000, the mean is higher at approximately
# $86,155 due to the presence of extreme high-income outliers. Compensation values
# exhibit substantial variability, with a wide interquartile range and a maximum
# value exceeding $16 million. This skewness suggests that median-based measures
# are more representative of typical earnings than the mean.

# %% [markdown]
# ### Summary

# %% [markdown]
# **In this lab, you focused on imputing missing values in the dataset.**
#
# - Use the <code>pandas.read_csv()</code> function to load a dataset from a CSV file into a DataFrame.
#
# - Download the dataset if it's not available online and specify the correct file path.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-27|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-26|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Hands_on_Lab_10_Normalizing_Data(1).ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Normalization Techniques**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on data normalization. This includes identifying compensation-related columns, applying normalization techniques, and visualizing the data distributions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Identify duplicate rows and remove them.
#
# - Check and handle missing values in key columns.
#
# - Identify and normalize compensation-related columns.
#
# - Visualize the effect of normalization techniques on data distributions.

# %% [markdown]
# -----

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# #### Step 1: Install and Import Libraries

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2: Load the Dataset into a DataFrame

# %% [markdown]
# We use the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# Display the first few rows to check if data is loaded correctly
# print(df.head())
df.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2                     I am a developer by profession
# 2            3                     I am a developer by profession
# 3            4                              I am learning to code
# 4            5                     I am a developer by profession
# 5            6                        I code primarily as a hobby
# 6            7  I am not primarily a developer, but I write co...
# 7            8                              I am learning to code
# 8            9                        I code primarily as a hobby
# 9           10                     I am a developer by profession
# 10          11  I used to be a developer by profession, but no...
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
df["ConvertedCompYearly"].isna().sum(), df.shape[0]
df["ConvertedCompYearly"].notna().sum()
# Out:
# np.int64(23435)

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ### Section 1: Handling Duplicates
# ##### Task 1: Identify and remove duplicate rows.

# %%
## Write your code here
duplicates = df[df.duplicated()] # From the DataFrame df, select only the rows that are duplicates, and store them in duplicates.
print(duplicates.shape[0]) # same as: print(len(duplicates)) (returns the number of rows)
# duplicates.head()
df = df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0
# 0

# %% [markdown]
# ### Section 2: Handling Missing Values
# ##### Task 2: Identify missing values in `CodingActivities`.

# %%
## Write your code here
missing_values = df['CodingActivities'].isnull()
print(missing_values.sum())
# Out:
# 10971

# %% [markdown]
# ##### Task 3: Impute missing values in CodingActivities with forward-fill.

# %%
## Write your code here
# Note: Forward-fill assumes that the previous value is a reasonable proxy. This assumption should always be stated.
df["CodingActivities"] = df["CodingActivities"].fillna(method="ffill")

# df['CodingActivities'] = df['CodingActivities'].fillna(method='ffill', inplace=True)
# missing_values = df['CodingActivities'].isnull()
# print(missing_values.sum())
# Out:
# /tmp/ipython-input-1267264145.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["CodingActivities"] = df["CodingActivities"].fillna(method="ffill")

# %% [markdown]
# **Note**:  Before normalizing ConvertedCompYearly, ensure that any missing values (NaN) in this column are handled appropriately. You can choose to either drop the rows containing NaN or replace the missing values with a suitable statistic (e.g., median or mean).

# %% [markdown]
# ### Section 3: Normalizing Compensation Data
# ##### Task 4: Identify compensation-related columns, such as ConvertedCompYearly.
# Normalization is commonly applied to compensation data to bring values within a comparable range. Here, you’ll identify ConvertedCompYearly or similar columns, which contain compensation information. This column will be used in the subsequent tasks for normalization.

# %%
## Write your code here
df["ConvertedCompYearly"].describe()
# Out:
# count    2.343500e+04
# mean     8.615529e+04
# std      1.867570e+05
# min      1.000000e+00
# 25%      3.271200e+04
# 50%      6.500000e+04
# 75%      1.079715e+05
# max      1.625660e+07
# Name: ConvertedCompYearly, dtype: float64

# %% [markdown]
# ##### Task 5: Normalize ConvertedCompYearly using Min-Max Scaling.
# Min-Max Scaling brings all values in a column to a 0-1 range, making it useful for comparing data across different scales. Here, you will apply Min-Max normalization to the ConvertedCompYearly column, creating a new column ConvertedCompYearly_MinMax with normalized values.

# %%
## Write your code here
# Apply Min-Max Scaling
df["ConvertedCompYearly_MinMax"] = (
    df["ConvertedCompYearly"] - df["ConvertedCompYearly"].min()
) / (
    df["ConvertedCompYearly"].max() - df["ConvertedCompYearly"].min()
)
df["ConvertedCompYearly_MinMax"].describe() # min value is 0 and Max is 1
df['ConvertedCompYearly_MinMax']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 65432   NaN
# 65433   NaN
# 65434   NaN
# 65435   NaN
# 65436   NaN
# Name: ConvertedCompYearly_MinMax, Length: 65437, dtype: float64

# %% [markdown]
# ##### Task 6: Apply Z-score Normalization to `ConvertedCompYearly`.
#
# Z-score normalization standardizes values by converting them to a distribution with a mean of 0 and a standard deviation of 1. This method is helpful for datasets with a Gaussian (normal) distribution. Here, you’ll calculate Z-scores for the ConvertedCompYearly column, saving the results in a new column ConvertedCompYearly_Zscore.

# %%
## Write your code here
# x = original value
# μ = mean of the column
# σ = standard deviation of the column
# Z-score : (x - μ)  / σ


mean_comp = df["ConvertedCompYearly"].mean()
std_comp = df["ConvertedCompYearly"].std()

df["ConvertedCompYearly_Zscore"] = (
    df["ConvertedCompYearly"] - mean_comp
) / std_comp
# df["ConvertedCompYearly_Zscore"].describe()

# %% [markdown]
# ### Section 4: Visualization of Normalized Data
# ##### Task 7: Visualize the distribution of `ConvertedCompYearly`, `ConvertedCompYearly_Normalized`, and `ConvertedCompYearly_Zscore`
#
# Visualization helps you understand how normalization changes the data distribution. In this task, create histograms for the original ConvertedCompYearly, as well as its normalized versions (ConvertedCompYearly_MinMax and ConvertedCompYearly_Zscore). This will help you compare how each normalization technique affects the data range and distribution.

# %%
# df["ConvertedCompYearly"].isna().sum(), df.shape[0]
df["ConvertedCompYearly_MinMax"].isna().sum(), df.shape[0]
# df["ConvertedCompYearly_Zscore"].isna().sum(), df.shape[0]
# Out:
# (np.int64(42002), 65437)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 5))

# Original compensation
plt.subplot(1, 3, 1)
sns.histplot(df["ConvertedCompYearly"].dropna(), bins=50)
plt.title("ConvertedCompYearly (Original)")
plt.xlabel("Annual Compensation")
plt.ylabel("Frequency")

# Min-Max normalized
plt.subplot(1, 3, 2)
sns.histplot(df["ConvertedCompYearly_MinMax"].dropna(), bins=50)
plt.title("ConvertedCompYearly (Min-Max Scaled)")
plt.xlabel("Min-Max Value")
plt.ylabel("Frequency")

# Z-score normalized
plt.subplot(1, 3, 3)
sns.histplot(df["ConvertedCompYearly_Zscore"].dropna(), bins=50)
plt.title("ConvertedCompYearly (Z-score Normalized)")
plt.xlabel("Z-score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
## Write your code here
plt.figure(figsize=(12, 6))

# Compensation: The total amount of money a respondent earns from their work in one year.
# Original Data
plt.subplot(1, 3, 1)  # 1 → number of rows, 3 → number of columns, 1 → which subplot to draw in (from left to right)
plt.hist(df["ConvertedCompYearly"].dropna(), bins=100)
# plt.hist(df["ConvertedCompYearly"], bins=20, color="blue", edgecolor="black")
plt.title("Original Data")
plt.xlabel("ConvertedCompYearly")
plt.ylabel("Frequency")

# Min-Max normalized
plt.subplot(1, 3, 2)
plt.hist(df["ConvertedCompYearly_MinMax"].dropna(), bins=100)
plt.title("ConvertedCompYearly (Min-Max Scaled)")
plt.xlabel("Min-Max Value")
plt.ylabel("Frequency")

# Z-score normalized
plt.subplot(1, 3, 3)
plt.hist(df["ConvertedCompYearly_Zscore"].dropna(), bins=100)
plt.title("ConvertedCompYearly (Z-score Normalized)")
plt.xlabel("Z-score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you practiced essential normalization techniques, including:
#
# - Identifying and handling duplicate rows.
#
# - Checking for and imputing missing values.
#
# - Applying Min-Max scaling and Z-score normalization to compensation data.
#
# - Visualizing the impact of normalization on data distribution.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.

# %% [markdown]
# ---
#
# ## Section from `Lab_Data_Visualization.ipynb`

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on data visualization. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition and comparison of data.

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download the database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2026-01-23 07:37:31--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv.1’
#
# survey-data.csv.1   100%[===================>] 152.13M   151MB/s    in 1.0s
#
# 2026-01-23 07:37:32 (151 MB/s) - ‘survey-data.csv.1’ saved [159525875/159525875]

# %% [markdown]
# **Install and Import Necessary Python Libraries**
#
# Ensure that you have the required libraries installed to work with SQLite and Pandas:

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the CSV File into a Pandas DataFrame**
#
# Load the Stack Overflow survey data into a Pandas DataFrame:

# %%
# Read the CSV file
df = pd.read_csv('survey-data.csv')

# Display the first few rows of the data
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# **Create a SQLite Database and Insert the Data**
#
# Now, let's create a new SQLite database (`survey-data.sqlite`) and insert the data from the DataFrame into a table using the sqlite3 library:

# %%
import sqlite3

# Create a connection to the SQLite database or if the file does not exist, SQLite automatically creates it.
conn = sqlite3.connect('survey-data.sqlite')

# Write the dataframe to the SQLite database. 👉 Takes the pandas DataFrame df and writes it into the SQLite database as a table named main.
df.to_sql('main', conn, if_exists='replace', index=False)


# Close the connection
conn.close()

# %% [markdown]
# **Verify the Data in the SQLite Database**
# Verify that the data has been correctly inserted into the SQLite database by running a simple query:

# %%
# Reconnect to the SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Run a simple query to check the data
QUERY = "SELECT * FROM main LIMIT 5"
df_check = pd.read_sql_query(QUERY, conn) # 👉 Runs an SQL query on the SQLite database and loads the result into a pandas DataFrame called df_check.

# Display the results
# print(df_check)
df_check.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time       None  Apples
# 4   Student, full-time       None  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                               None
# ...

# %% [markdown]
# ## Demo: Running an SQL Query

# %% [markdown]
# Count the number of rows in the table named 'main'

# %%
QUERY = """
SELECT COUNT(*)
FROM main
"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# ## Demo: Listing All Tables

# %% [markdown]
# To view the names of all tables in the database:

# %%
QUERY = """
SELECT name as Table_Name FROM sqlite_master
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# ## Demo: Running a Group By Query
#
# For example, you can group data by a specific column, like Age, to get the count of respondents in each age group:

# %%
QUERY = """
SELECT Age, COUNT(*) as count
FROM main
GROUP BY Age
ORDER BY Age
"""
# COUNT(*), counts the number of 'Rows' for each age group (because of group by)
pd.read_sql_query(QUERY, conn)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Demo: Describing a table
#
# Use this query to get the schema of a specific table, main in this case:

# %%
table_name = 'main'

# This query is telling “SQLite, show me the SQL you used to create the main table.”
QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY, conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "main" (
# "ResponseId" INTEGER,
#   "MainBranch" TEXT,
#   "Age" TEXT,
#   "Employment" TEXT,
#   "RemoteWork" TEXT,
#   "Check" TEXT,
#   "CodingActivities" TEXT,
#   "EdLevel" TEXT,
#   "LearnCode" TEXT,
#   "LearnCodeOnline" TEXT,
#   "TechDoc" TEXT,
#   "YearsCode" TEXT,
#   "YearsCodePro" TEXT,
#   "DevType" TEXT,
#   "OrgSize" TEXT,
#   "PurchaseInfluence" TEXT,
#   "BuyNewTool" TEXT,
#   "BuildvsBuy" TEXT,
#   "TechEndorse" TEXT,
#   "Country" TEXT,
#   "Currency" TEXT,
#   "CompTotal" REAL,
#   "LanguageHaveWorkedWith" TEXT,
#   "LanguageWantToWorkWith" TEXT,
#   "LanguageAdmired" TEXT,
#   "DatabaseHaveWorkedWith" TEXT,
#   "DatabaseWantToWorkWith" TEXT,
#   "DatabaseAdmired" TEXT,
#   "PlatformHaveWorkedWith" TEXT,
#   "PlatformWantToWorkWith" TEXT,
#   "PlatformAdmired" TEXT,
#   "WebframeHaveWorkedWith" TEXT,
#   "WebframeWantToWorkWith" TEXT,
#   "WebframeAdmired" TEXT,
#   "EmbeddedHaveWorkedWith" TEXT,
#   "EmbeddedWantToWorkWith" TEXT,
# ...

# %% [markdown]
# ## Hands-on Lab

# %% [markdown]
# ### Visualizing the Distribution of Data
#
# **Histograms**
#
# Plot a histogram of CompTotal (Total Compensation).

# %%
## Write your code here

conn = sqlite3.connect('survey-data.sqlite')
QUERY = """
SELECT CompTotal
FROM main
WHERE CompTotal IS NOT NULL
"""
df_comp = pd.read_sql_query(QUERY, conn)
df_comp.head()

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df_comp["CompTotal"], bins=30)
plt.xlabel("CompTotal (Total Compensation)")
plt.ylabel("Frequency")
plt.title("Histogram of Total Compensation (CompTotal)")
plt.show()

# %% [markdown]
# **Box Plots**
#
# Plot a box plot of Age.

# %%
## Write your code here

QUERY = """
SELECT Age
FROM main
WHERE Age IS NOT NULL
"""
df_age = pd.read_sql_query(QUERY, conn)

print(df_age.head())
print(df_age.dtypes)

# Mapping age groups to numeric values to be able to produce boxplot
age_mapping = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70
}

df_age['Age_numeric'] = df_age['Age'].map(age_mapping)
df_age = df_age.dropna()

# Plotting

plt.figure(figsize=(6,4))
plt.boxplot(df_age['Age_numeric'])
plt.ylabel('Age')
plt.title('Box Plot of Age')
plt.show()
# Out:
#                   Age
# 0  Under 18 years old
# 1     35-44 years old
# 2     45-54 years old
# 3     18-24 years old
# 4     18-24 years old
# Age    object
# dtype: object

# %% [markdown]
# ### Visualizing Relationships in Data
#
# **Scatter Plots**
#
# Create a scatter plot of Age and WorkExp.

# %%
## Write your code here
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# -------------------------------
# SQL: Extract Age and WorkExp
# -------------------------------
QUERY = """
SELECT Age, WorkExp
FROM main
WHERE Age IS NOT NULL
  AND WorkExp IS NOT NULL
"""
df_aw = pd.read_sql_query(QUERY, conn)

# -------------------------------
# Map Age groups to numeric values
# -------------------------------
age_mapping = {
    'Under 18 years old': 16,
    '18-24 years old': 21,
    '25-34 years old': 29.5,
    '35-44 years old': 39.5,
    '45-54 years old': 49.5,
    '55-64 years old': 59.5,
    '65 years or older': 70
}

df_aw['Age_numeric'] = df_aw['Age'].map(age_mapping)
df_aw = df_aw.dropna()

# -------------------------------
# Scatter plot: Age vs WorkExp
# -------------------------------
plt.figure(figsize=(7, 5))
plt.scatter(df_aw['Age_numeric'], df_aw['WorkExp'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Work Experience (Years)')
plt.title('Scatter Plot of Age vs Work Experience')
plt.show()

# -------------------------------
# Scatter plot with trend line
# -------------------------------
z = np.polyfit(df_aw['Age_numeric'], df_aw['WorkExp'], 1)
p = np.poly1d(z)

plt.figure(figsize=(7, 5))
plt.scatter(df_aw['Age_numeric'], df_aw['WorkExp'], alpha=0.5)
plt.plot(df_aw['Age_numeric'], p(df_aw['Age_numeric']))
plt.xlabel('Age')
plt.ylabel('Work Experience (Years)')
plt.title('Age vs Work Experience with Trend Line')
plt.show()

# %% [markdown]
# **Bubble Plots**
#
# Create a bubble plot of `TimeSearching` and `Frustration` using the Age column as the bubble size.

# %%
## Write your code here

import pandas as pd
import matplotlib.pyplot as plt

# ----------------------------------
# SQL: Extract required columns
# ----------------------------------
QUERY = """
SELECT Age, TimeSearching, Frustration
FROM main
WHERE Age IS NOT NULL
  AND TimeSearching IS NOT NULL
  AND Frustration IS NOT NULL
"""
df_bubble = pd.read_sql_query(QUERY, conn)

# ----------------------------------
# Encode categorical columns safely
# ----------------------------------
df_bubble['Age_numeric'] = df_bubble['Age'].astype('category').cat.codes + 1
df_bubble['TimeSearching_num'] = df_bubble['TimeSearching'].astype('category').cat.codes + 1
df_bubble['Frustration_num'] = df_bubble['Frustration'].astype('category').cat.codes + 1

# ----------------------------------
# Bubble plot
# ----------------------------------
plt.figure(figsize=(8, 6))
plt.scatter(
    df_bubble['TimeSearching_num'],
    df_bubble['Frustration_num'],
    s=df_bubble['Age_numeric'] * 20,
    alpha=0.5
)

plt.xlabel('Time Spent Searching (Low → High)')
plt.ylabel('Frustration Level (Low → High)')
plt.title('Bubble Plot of Time Searching vs Frustration (Bubble Size = Age)')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ### Visualizing Composition of Data
#
# **Pie Charts**
#
# Create a pie chart of the top 5 databases(`DatabaseWantToWorkWith`) that respondents wish to learn next year.

# %%
## Write your code here

# ----------------------------------
# SQL: Extract DatabaseWantToWorkWith
# ----------------------------------
QUERY = """
SELECT DatabaseWantToWorkWith
FROM main
WHERE DatabaseWantToWorkWith IS NOT NULL
"""
df_db = pd.read_sql_query(QUERY, conn)

# ----------------------------------
# Split multiple databases into rows
# ----------------------------------
df_db['Database'] = df_db['DatabaseWantToWorkWith'].str.split(';')
df_db = df_db.explode('Database')

# Clean whitespace
df_db['Database'] = df_db['Database'].str.strip()

# ----------------------------------
# Get top 5 databases
# ----------------------------------
top5 = df_db['Database'].value_counts().head(5)

# ----------------------------------
# Pie chart
# ----------------------------------
plt.figure(figsize=(7, 7))
plt.pie(
    top5.values,
    labels=top5.index,
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Top 5 Databases Respondents Want to Work With Next Year')
plt.show()

# %% [markdown]
# **Stacked Charts**
#
# Create a stacked bar chart of median `TimeSearching` and `TimeAnswering` for the age group 30 to 35.

# %%
## Write your code here

# ----------------------------------
# SQL: Extract required columns
# ----------------------------------
QUERY = """
SELECT Age, TimeSearching, TimeAnswering
FROM main
WHERE Age IS NOT NULL
  AND TimeSearching IS NOT NULL
  AND TimeAnswering IS NOT NULL
"""
df_time = pd.read_sql_query(QUERY, conn)

# ----------------------------------
# Filter age group ~30–35 (25–34 years old)
# ----------------------------------
df_time = df_time[df_time['Age'] == '25-34 years old']

# ----------------------------------
# Encode time categories to numeric scale
# ----------------------------------
time_mapping = {
    'Less than 15 minutes a day': 1,
    '15-30 minutes a day': 2,
    '30-60 minutes a day': 3,
    '1-2 hours a day': 4,
    '2-4 hours a day': 5,
    'More than 4 hours a day': 6
}

df_time['TimeSearching_num'] = df_time['TimeSearching'].map(time_mapping)
df_time['TimeAnswering_num'] = df_time['TimeAnswering'].map(time_mapping)

df_time = df_time.dropna()

# ----------------------------------
# Calculate median values
# ----------------------------------
median_values = df_time[['TimeSearching_num', 'TimeAnswering_num']].median()

# ----------------------------------
# Stacked bar chart
# ----------------------------------
plt.figure(figsize=(6, 5))
plt.bar(
    ['Age 30–35'],
    [median_values['TimeSearching_num']],
    label='Time Searching'
)
plt.bar(
    ['Age 30–35'],
    [median_values['TimeAnswering_num']],
    bottom=[median_values['TimeSearching_num']],
    label='Time Answering'
)

plt.ylabel('Median Time (Low → High)')
plt.title('Median Time Searching and Answering (Age 30–35)')
plt.legend()
plt.show()

# %% [markdown]
# ### Visualizing Comparison of Data
#
# **Line Chart**
#
# Plot the median `CompTotal` for all ages from 45 to 60.

# %%
## Write your code here

# ----------------------------------
# SQL: Extract Age and CompTotal
# ----------------------------------
QUERY = """
SELECT Age, CompTotal
FROM main
WHERE Age IS NOT NULL
  AND CompTotal IS NOT NULL
"""
df_comp = pd.read_sql_query(QUERY, conn)

# ----------------------------------
# Keep only ages 45–60 (survey groups)
# ----------------------------------
df_comp = df_comp[df_comp['Age'].isin([
    '45-54 years old',
    '55-64 years old'
])]

# ----------------------------------
# Convert compensation to numeric
# ----------------------------------
df_comp['CompTotal'] = pd.to_numeric(df_comp['CompTotal'], errors='coerce')

# Remove unrealistic / invalid values
df_comp = df_comp[df_comp['CompTotal'].between(1000, 1_000_000)]

# ----------------------------------
# Compute median CompTotal by Age group
# ----------------------------------
median_comp = (
    df_comp
    .groupby('Age')['CompTotal']
    .median()
    .reset_index()
)

# Ensure correct order for line chart
age_order = ['45-54 years old', '55-64 years old']
median_comp['Age'] = pd.Categorical(
    median_comp['Age'],
    categories=age_order,
    ordered=True
)
median_comp = median_comp.sort_values('Age')

# ----------------------------------
# Line chart
# ----------------------------------
plt.figure(figsize=(7, 5))
plt.plot(
    median_comp['Age'],
    median_comp['CompTotal'],
    marker='o'
)

plt.xlabel('Age Group')
plt.ylabel('Median Total Compensation')
plt.title('Median Total Compensation for Ages 45–60')
plt.show()

# %% [markdown]
# **Bar Chart**
#
# Create a horizontal bar chart using the `MainBranch` column.

# %%
## Write your code here

# ----------------------------------
# SQL: Extract MainBranch
# ----------------------------------
QUERY = """
SELECT MainBranch
FROM main
WHERE MainBranch IS NOT NULL
"""
df_branch = pd.read_sql_query(QUERY, conn)

# ----------------------------------
# Count respondents by MainBranch
# ----------------------------------
branch_counts = df_branch['MainBranch'].value_counts()

# ----------------------------------
# Horizontal bar chart
# ----------------------------------
plt.figure(figsize=(8, 5))
branch_counts.plot(kind='barh')

plt.xlabel('Number of Respondents')
plt.ylabel('Main Branch')
plt.title('Distribution of Respondents by Main Branch')
plt.show()

conn.close()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you focused on extracting and visualizing data from an RDBMS using SQL queries and SQLite. You applied various visualization techniques, including:
#
# - Histograms to display the distribution of CompTotal.
# - Box plots to show the spread of ages.
# - Scatter plots and bubble plots to explore relationships between variables like Age, WorkExp, `TimeSearching` and `TimeAnswering`.
# - Pie charts and stacked charts to visualize the composition of data.
# - Line charts and bar charts to compare data across categories.

# %% [markdown]
# ### Close the Database Connection
#
# Once the lab is complete, ensure to close the database connection:

# %%
conn.close()

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
